# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#import" data-toc-modified-id="import-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>import</a></span></li></ul></li><li><span><a href="#划分数据集" data-toc-modified-id="划分数据集-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>划分数据集</a></span><ul class="toc-item"><li><span><a href="#目标-status" data-toc-modified-id="目标-status-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>目标 status</a></span></li><li><span><a href="#划分数据集" data-toc-modified-id="划分数据集-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>划分数据集</a></span></li><li><span><a href="#数据类型" data-toc-modified-id="数据类型-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>数据类型</a></span><ul class="toc-item"><li><span><a href="#object" data-toc-modified-id="object-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>object</a></span></li><li><span><a href="#int64" data-toc-modified-id="int64-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>int64</a></span></li><li><span><a href="#float64" data-toc-modified-id="float64-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>float64</a></span></li></ul></li><li><span><a href="#数据描述" data-toc-modified-id="数据描述-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>数据描述</a></span></li></ul></li><li><span><a href="#特征工程" data-toc-modified-id="特征工程-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>特征工程</a></span><ul class="toc-item"><li><span><a href="#特征预处理" data-toc-modified-id="特征预处理-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>特征预处理</a></span><ul class="toc-item"><li><span><a href="#cols_to_del" data-toc-modified-id="cols_to_del-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>cols_to_del</a></span></li><li><span><a href="#cols_0_to_1" data-toc-modified-id="cols_0_to_1-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>cols_0_to_1</a></span></li><li><span><a href="#cols_catg" data-toc-modified-id="cols_catg-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>cols_catg</a></span></li><li><span><a href="#cols_date" data-toc-modified-id="cols_date-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>cols_date</a></span></li><li><span><a href="#cols_nums" data-toc-modified-id="cols_nums-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>cols_nums</a></span></li></ul></li><li><span><a href="#处理空值" data-toc-modified-id="处理空值-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>处理空值</a></span><ul class="toc-item"><li><span><a href="#删除2行缺失较多的行" data-toc-modified-id="删除2行缺失较多的行-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>删除2行缺失较多的行</a></span></li><li><span><a href="#分类类型缺失值处理" data-toc-modified-id="分类类型缺失值处理-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>分类类型缺失值处理</a></span><ul class="toc-item"><li><span><a href="#cols_catg" data-toc-modified-id="cols_catg-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>cols_catg</a></span></li></ul></li><li><span><a href="#cols_date-日期型数据处理" data-toc-modified-id="cols_date-日期型数据处理-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>cols_date 日期型数据处理</a></span></li><li><span><a href="#cols_0_to_1" data-toc-modified-id="cols_0_to_1-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>cols_0_to_1</a></span></li><li><span><a href="#cols_nums" data-toc-modified-id="cols_nums-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>cols_nums</a></span><ul class="toc-item"><li><span><a href="#cols_nums_with_day" data-toc-modified-id="cols_nums_with_day-2.2.5.1"><span class="toc-item-num">2.2.5.1&nbsp;&nbsp;</span>cols_nums_with_day</a></span></li><li><span><a href="#其余填充为中位数" data-toc-modified-id="其余填充为中位数-2.2.5.2"><span class="toc-item-num">2.2.5.2&nbsp;&nbsp;</span>其余填充为中位数</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#特征权重" data-toc-modified-id="特征权重-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>特征权重</a></span><ul class="toc-item"><li><span><a href="#IV值" data-toc-modified-id="IV值-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>IV值</a></span></li><li><span><a href="#随机森林" data-toc-modified-id="随机森林-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>随机森林</a></span></li></ul></li><li><span><a href="#问题" data-toc-modified-id="问题-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>问题</a></span></li></ul></div>

# %% [markdown]
# 任务2 - 特征工程（2天）
#
# - 特征衍生
# - 特征挑选：分别用IV值和随机森林等进行特征选择
# - ……以及你能想到特征工程处理

# %%
ls
# Out:
# 2019-08-09/              data.csv                 task01_52_lmingzhi.html
# README.md                others/                  task02.ipynb
# Untitled.ipynb           task01.ipynb

# %% [markdown]
# ## import

# %%
import json, io, re, os, time
from datetime import datetime, timedelta
from pandas.io.json import json_normalize
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn

from collections import defaultdict, Counter
# %matplotlib inline

# plt.rc('figure', figsize = (8.4,5))
# plt.rcParams['font.family'] = ['Arial Unicode MS'] 
# plt.rcParams['axes.unicode_minus'] = False

# %%
# 设置显示行数
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
# 限制列宽，每列最多显示15个字符
# pd.set_option('display.max_colwidth', 15)

# %% [markdown]
# # 划分数据集

# %%
# !head -2 data.csv

# %%
df = pd.read_csv('data.csv', encoding='gb18030')

# %%
df.shape
# Out:
# (4754, 90)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'custid', 'trade_no', 'bank_card_no',
#        'low_volume_percent', 'middle_volume_percent',
#        'take_amount_in_later_12_month_highest',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'repayment_capability', 'is_high_user', 'number_of_trans_from_2011',
#        'first_transaction_time', 'historical_trans_amount',
#        'historical_trans_day', 'rank_trad_1_month', 'trans_amount_3_month',
#        'avg_consume_less_12_valid_month', 'abs',
#        'top_trans_count_last_1_month', 'avg_price_last_12_month',
#        'avg_price_top_last_12_valid_month', 'reg_preference_for_trad',
#        'trans_top_time_last_1_month', 'trans_top_time_last_6_month',
#        'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
#        'cross_consume_count_last_1_month',
#        'trans_fail_top_count_enum_last_1_month',
#        'trans_fail_top_count_enum_last_6_month',
#        'trans_fail_top_count_enum_last_12_month',
#        'consume_mini_time_last_1_month',
#        'max_cumulative_consume_later_1_month',
#        'max_consume_count_later_6_month',
#        'railway_consume_count_last_12_month',
#        'pawns_auctions_trusts_consume_last_1_month',
#        'pawns_auctions_trusts_consume_last_6_month',
#        'jewelry_consume_count_last_6_month', 'status', 'source',
#        'first_transaction_day', 'trans_day_last_12_month', 'id_name',
#        'apply_score', 'apply_credibility', 'query_org_count',
#        'query_finance_count', 'query_cash_count', 'query_sum_count',
#        'latest_query_time', 'latest_one_month_apply',
#        'latest_three_month_apply', 'latest_six_month_apply', 'loans_score',
#        'loans_credibility_behavior', 'loans_count', 'loans_settle_count',
#        'loans_overdue_count', 'loans_org_count_behavior',
#        'consfin_org_count_behavior', 'loans_cash_count',
#        'latest_one_month_loan', 'latest_three_month_loan',
#        'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee',
#        'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
#        'loans_latest_time', 'loans_credit_limit', 'loans_credibility_limit',
#        'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
#        'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility',
#        'consfin_org_count_current', 'consfin_product_count',
#        'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day',
#        'loans_latest_day'],
#       dtype='object')

# %%
del df['Unnamed: 0']

# %%
df.head(3).T
# Out:
#                                                                            0  \
# custid                                                               2791858
# trade_no                                    20180507115231274000000023057383
# bank_card_no                                                             卡号1
# low_volume_percent                                                      0.01
# middle_volume_percent                                                   0.99
# take_amount_in_later_12_month_highest                                      0
# trans_amount_increase_rate_lately                                        0.9
# trans_activity_month                                                    0.55
# trans_activity_day                                                     0.313
# transd_mcc                                                                17
# trans_days_interval_filter                                                27
# trans_days_interval                                                       26
# regional_mobility                                                          3
# student_feature                                                          NaN
# repayment_capability                                                   19890
# is_high_user                                                               0
# number_of_trans_from_2011                                                 30
# first_transaction_time                                           2.01308e+07
# historical_trans_amount                                               149050
# historical_trans_day                                                     151
# rank_trad_1_month                                                        0.4
# trans_amount_3_month                                                   34030
# avg_consume_less_12_valid_month                                            7
# abs                                                                     3920
# top_trans_count_last_1_month                                            0.15
# avg_price_last_12_month                                                 1020
# avg_price_top_last_12_valid_month                                       0.55
# reg_preference_for_trad                                                 一线城市
# trans_top_time_last_1_month                                                4
# trans_top_time_last_6_month                                               19
# consume_top_time_last_1_month                                              4
# consume_top_time_last_6_month                                             19
# cross_consume_count_last_1_month                                           1
# trans_fail_top_count_enum_last_1_month                                     1
# trans_fail_top_count_enum_last_6_month                                     2
# trans_fail_top_count_enum_last_12_month                                    2
# consume_mini_time_last_1_month                                             5
# max_cumulative_consume_later_1_month                                    2170
# max_consume_count_later_6_month                                            6
# railway_consume_count_last_12_month                                        0
# pawns_auctions_trusts_consume_last_1_month                              1970
# pawns_auctions_trusts_consume_last_6_month                             18040
# jewelry_consume_count_last_6_month                                         0
# status                                                                     1
# source                                                                    xs
# first_transaction_day                                                   1738
# trans_day_last_12_month                                                   85
# id_name                                                                   蒋红
# apply_score                                                              583
# apply_credibility                                                         79
# query_org_count                                                            8
# query_finance_count                                                        2
# query_cash_count                                                           6
# query_sum_count                                                           10
# latest_query_time                                                 2018-04-25
# latest_one_month_apply                                                     2
# latest_three_month_apply                                                   5
# latest_six_month_apply                                                     8
# loans_score                                                              552
# loans_credibility_behavior                                                73
# loans_count                                                               37
# loans_settle_count                                                        34
# loans_overdue_count                                                        2
# loans_org_count_behavior                                                  10
# consfin_org_count_behavior                                                 1
# loans_cash_count                                                           9
# latest_one_month_loan                                                      1
# latest_three_month_loan                                                    1
# latest_six_month_loan                                                     13
# history_suc_fee                                                           37
# history_fail_fee                                                           7
# latest_one_month_suc                                                       1
# latest_one_month_fail                                                      0
# loans_long_time                                                          341
# loans_latest_time                                                 2018-04-19
# loans_credit_limit                                                      2200
# loans_credibility_limit                                                   72
# loans_org_count_current                                                    9
# loans_product_count                                                       10
# loans_max_limit                                                         2900
# loans_avg_limit                                                         1688
# consfin_credit_limit                                                    1200
# consfin_credibility                                                       75
# consfin_org_count_current                                                  1
# consfin_product_count                                                      2
# consfin_max_limit                                                       1200
# consfin_avg_limit                                                       1200
# latest_query_day                                                          12
# loans_latest_day                                                          18
#
#                                                                            1  \
# custid                                                                534047
# trade_no                                    20180507121002192000000023073000
# bank_card_no                                                             卡号1
# low_volume_percent                                                      0.02
# middle_volume_percent                                                   0.94
# take_amount_in_later_12_month_highest                                   2000
# trans_amount_increase_rate_lately                                       1.28
# trans_activity_month                                                       1
# trans_activity_day                                                     0.458
# transd_mcc                                                                19
# trans_days_interval_filter                                                30
# trans_days_interval                                                       14
# regional_mobility                                                          4
# student_feature                                                            1
# repayment_capability                                                   16970
# is_high_user                                                               0
# number_of_trans_from_2011                                                 23
# first_transaction_time                                           2.01604e+07
# historical_trans_amount                                               302910
# historical_trans_day                                                     224
# rank_trad_1_month                                                       0.35
# trans_amount_3_month                                                   10590
# avg_consume_less_12_valid_month                                            5
# abs                                                                     6950
# top_trans_count_last_1_month                                            0.05
# avg_price_last_12_month                                                 1210
# avg_price_top_last_12_valid_month                                        0.5
# reg_preference_for_trad                                                 一线城市
# trans_top_time_last_1_month                                               13
# trans_top_time_last_6_month                                               30
# consume_top_time_last_1_month                                             13
# consume_top_time_last_6_month                                             30
# cross_consume_count_last_1_month                                           0
# trans_fail_top_count_enum_last_1_month                                     0
# trans_fail_top_count_enum_last_6_month                                     3
# trans_fail_top_count_enum_last_12_month                                    3
# consume_mini_time_last_1_month                                           330
# max_cumulative_consume_later_1_month                                    2100
# max_consume_count_later_6_month                                            9
# railway_consume_count_last_12_month                                        0
# pawns_auctions_trusts_consume_last_1_month                              1820
# pawns_auctions_trusts_consume_last_6_month                             15680
# jewelry_consume_count_last_6_month                                         0
# status                                                                     0
# source                                                                    xs
# first_transaction_day                                                    779
# trans_day_last_12_month                                                   84
# id_name                                                                  崔向朝
# apply_score                                                              653
# apply_credibility                                                         73
# query_org_count                                                            7
# query_finance_count                                                        4
# query_cash_count                                                           2
# query_sum_count                                                            8
# latest_query_time                                                 2018-05-03
# latest_one_month_apply                                                     2
# latest_three_month_apply                                                   6
# latest_six_month_apply                                                     8
# loans_score                                                              635
# loans_credibility_behavior                                                76
# loans_count                                                               37
# loans_settle_count                                                        36
# loans_overdue_count                                                        0
# loans_org_count_behavior                                                  17
# consfin_org_count_behavior                                                 5
# loans_cash_count                                                          12
# latest_one_month_loan                                                      2
# latest_three_month_loan                                                    2
# latest_six_month_loan                                                      8
# history_suc_fee                                                           49
# history_fail_fee                                                           4
# latest_one_month_suc                                                       2
# latest_one_month_fail                                                      1
# loans_long_time                                                          353
# loans_latest_time                                                 2018-05-05
# loans_credit_limit                                                      2000
# loans_credibility_limit                                                   74
# loans_org_count_current                                                   12
# loans_product_count                                                       12
# loans_max_limit                                                         3500
# loans_avg_limit                                                         1758
# consfin_credit_limit                                                   15100
# consfin_credibility                                                       80
# consfin_org_count_current                                                  5
# consfin_product_count                                                      6
# consfin_max_limit                                                      22800
# consfin_avg_limit                                                       9360
# latest_query_day                                                           4
# loans_latest_day                                                           2
#
#                                                                            2
# custid                                                               2849787
# trade_no                                    20180507125159718000000023114911
# bank_card_no                                                             卡号1
# low_volume_percent                                                      0.04
# middle_volume_percent                                                   0.96
# take_amount_in_later_12_month_highest                                      0
# trans_amount_increase_rate_lately                                          1
# trans_activity_month                                                       1
# trans_activity_day                                                     0.114
# transd_mcc                                                                13
# trans_days_interval_filter                                                68
# trans_days_interval                                                       22
# regional_mobility                                                          1
# student_feature                                                          NaN
# repayment_capability                                                    9710
# is_high_user                                                               0
# number_of_trans_from_2011                                                  9
# first_transaction_time                                           2.01706e+07
# historical_trans_amount                                                11520
# historical_trans_day                                                      31
# rank_trad_1_month                                                          1
# trans_amount_3_month                                                    5710
# avg_consume_less_12_valid_month                                            5
# abs                                                                      840
# top_trans_count_last_1_month                                            0.65
# avg_price_last_12_month                                                  570
# avg_price_top_last_12_valid_month                                       0.65
# reg_preference_for_trad                                                 一线城市
# trans_top_time_last_1_month                                                0
# trans_top_time_last_6_month                                               68
# consume_top_time_last_1_month                                              0
# consume_top_time_last_6_month                                             68
# cross_consume_count_last_1_month                                           0
# trans_fail_top_count_enum_last_1_month                                     3
# trans_fail_top_count_enum_last_6_month                                     6
# trans_fail_top_count_enum_last_12_month                                    6
# consume_mini_time_last_1_month                                             0
# max_cumulative_consume_later_1_month                                       0
# max_consume_count_later_6_month                                            3
# railway_consume_count_last_12_month                                        0
# pawns_auctions_trusts_consume_last_1_month                                 0
# pawns_auctions_trusts_consume_last_6_month                                 0
# jewelry_consume_count_last_6_month                                         0
# status                                                                     1
# source                                                                    xs
# first_transaction_day                                                    338
# trans_day_last_12_month                                                   95
# id_name                                                                  王中云
# apply_score                                                              654
# apply_credibility                                                         76
# query_org_count                                                           11
# query_finance_count                                                        5
# query_cash_count                                                           5
# query_sum_count                                                           16
# latest_query_time                                                 2018-05-05
# latest_one_month_apply                                                     5
# latest_three_month_apply                                                   5
# latest_six_month_apply                                                    14
# loans_score                                                              633
# loans_credibility_behavior                                                83
# loans_count                                                                4
# loans_settle_count                                                         2
# loans_overdue_count                                                        0
# loans_org_count_behavior                                                   3
# consfin_org_count_behavior                                                 1
# loans_cash_count                                                           2
# latest_one_month_loan                                                      2
# latest_three_month_loan                                                    2
# latest_six_month_loan                                                      4
# history_suc_fee                                                            2
# history_fail_fee                                                           2
# latest_one_month_suc                                                       1
# latest_one_month_fail                                                      1
# loans_long_time                                                          157
# loans_latest_time                                                 2018-05-01
# loans_credit_limit                                                      1500
# loans_credibility_limit                                                   77
# loans_org_count_current                                                    2
# loans_product_count                                                        2
# loans_max_limit                                                         1600
# loans_avg_limit                                                         1250
# consfin_credit_limit                                                    4200
# consfin_credibility                                                       87
# consfin_org_count_current                                                  1
# consfin_product_count                                                      1
# consfin_max_limit                                                       4200
# consfin_avg_limit                                                       4200
# latest_query_day                                                           2
# loans_latest_day                                                           6

# %% [markdown]
# ## 目标 status

# %%
df.status.fillna('null').value_counts()
# Out:
# 0    3561
# 1    1193
# Name: status, dtype: int64

# %% [markdown]
# ## 划分数据集

# %%
# conda install sklearn
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df, test_size = 0.3, random_state=2018)

# %%
train_set.shape
# Out:
# (3327, 89)

# %%
test_set.shape
# Out:
# (1427, 89)

# %%
df.shape
# Out:
# (4754, 89)

# %% [markdown]
# ## 数据类型

# %%
# 数据类型数量
train_set.dtypes.value_counts()
# Out:
# float64    70
# int64      12
# object      7
# dtype: int64

# %% [markdown]
# ### object

# %%
df_types = train_set.dtypes
cond = df_types == 'object'
df_types[cond].index
# Out:
# Index(['trade_no', 'bank_card_no', 'reg_preference_for_trad', 'source',
#        'id_name', 'latest_query_time', 'loans_latest_time'],
#       dtype='object')

# %%
test_set[df_types[cond].index].head(3).T
# Out:
#                                                      2248  \
# trade_no                 20180507115658623000000388217488
# bank_card_no                                          卡号1
# reg_preference_for_trad                              一线城市
# source                                                 xs
# id_name                                               郭二燊
# latest_query_time                              2018-04-13
# loans_latest_time                              2018-05-01
#
#                                                      3959  \
# trade_no                 20180507115833078000000388221695
# bank_card_no                                          卡号1
# reg_preference_for_trad                              一线城市
# source                                                 xs
# id_name                                                明磊
# latest_query_time                              2018-04-14
# loans_latest_time                              2018-03-26
#
#                                                      2251
# trade_no                 20180504175527473000000021273393
# bank_card_no                                          卡号1
# reg_preference_for_trad                              一线城市
# source                                                 xs
# id_name                                               王维策
# latest_query_time                              2018-04-24
# loans_latest_time                              2018-04-15

# %% [markdown]
# ### int64

# %%
df_types = train_set.dtypes
cond = df_types == 'int64'
df_types[cond].index
# Out:
# Index(['custid', 'take_amount_in_later_12_month_highest',
#        'repayment_capability', 'is_high_user', 'historical_trans_amount',
#        'trans_amount_3_month', 'abs', 'avg_price_last_12_month',
#        'max_cumulative_consume_later_1_month',
#        'pawns_auctions_trusts_consume_last_1_month',
#        'pawns_auctions_trusts_consume_last_6_month', 'status'],
#       dtype='object')

# %%
test_set[df_types[cond].index].head(3).T
# Out:
#                                                2248     3959    2251
# custid                                      2179871  2689718   47426
# take_amount_in_later_12_month_highest             0     1500    3000
# repayment_capability                           4650     2540   28160
# is_high_user                                      0        0       0
# historical_trans_amount                      168590   227470  959780
# trans_amount_3_month                          23060    43810  114140
# abs                                           19020    10040    6110
# avg_price_last_12_month                        1580     1240    1660
# max_cumulative_consume_later_1_month              0     1970    2290
# pawns_auctions_trusts_consume_last_1_month        0        0    1150
# pawns_auctions_trusts_consume_last_6_month    21920    28890   90330
# status                                            0        0       1

# %% [markdown]
# ### float64

# %%
df_types = train_set.dtypes
cond = df_types == 'float64'
df_types[cond].index
# Out:
# Index(['low_volume_percent', 'middle_volume_percent',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'number_of_trans_from_2011', 'first_transaction_time',
#        'historical_trans_day', 'rank_trad_1_month',
#        'avg_consume_less_12_valid_month', 'top_trans_count_last_1_month',
#        'avg_price_top_last_12_valid_month', 'trans_top_time_last_1_month',
#        'trans_top_time_last_6_month', 'consume_top_time_last_1_month',
#        'consume_top_time_last_6_month', 'cross_consume_count_last_1_month',
#        'trans_fail_top_count_enum_last_1_month',
#        'trans_fail_top_count_enum_last_6_month',
#        'trans_fail_top_count_enum_last_12_month',
#        'consume_mini_time_last_1_month', 'max_consume_count_later_6_month',
#        'railway_consume_count_last_12_month',
#        'jewelry_consume_count_last_6_month', 'first_transaction_day',
#        'trans_day_last_12_month', 'apply_score', 'apply_credibility',
#        'query_org_count', 'query_finance_count', 'query_cash_count',
#        'query_sum_count', 'latest_one_month_apply', 'latest_three_month_apply',
#        'latest_six_month_apply', 'loans_score', 'loans_credibility_behavior',
#        'loans_count', 'loans_settle_count', 'loans_overdue_count',
#        'loans_org_count_behavior', 'consfin_org_count_behavior',
#        'loans_cash_count', 'latest_one_month_loan', 'latest_three_month_loan',
#        'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee',
#        'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
#        'loans_credit_limit', 'loans_credibility_limit',
#        'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
#        'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility',
#        'consfin_org_count_current', 'consfin_product_count',
#        'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day',
#        'loans_latest_day'],
#       dtype='object')

# %%
test_set[df_types[cond].index].head(3).T
# Out:
#                                                  2248         3959  \
# low_volume_percent                       0.000000e+00         0.01
# middle_volume_percent                    1.000000e+00         0.94
# trans_amount_increase_rate_lately        3.500000e-01         0.51
# trans_activity_month                     8.300000e-01         0.61
# trans_activity_day                       3.970000e-01         0.50
# transd_mcc                               1.800000e+01        21.00
# trans_days_interval_filter               3.300000e+01        31.00
# trans_days_interval                      1.100000e+01        17.00
# regional_mobility                        3.000000e+00         3.00
# student_feature                                   NaN         1.00
# number_of_trans_from_2011                2.500000e+01        19.00
# first_transaction_time                   2.015091e+07  20150828.00
# historical_trans_day                     2.290000e+02       187.00
# rank_trad_1_month                        1.000000e+00         0.40
# avg_consume_less_12_valid_month          7.000000e+00         8.00
# top_trans_count_last_1_month             1.000000e+00         0.40
# avg_price_top_last_12_valid_month        4.500000e-01         0.50
# trans_top_time_last_1_month              0.000000e+00        19.00
# trans_top_time_last_6_month              1.200000e+01        19.00
# consume_top_time_last_1_month            0.000000e+00        19.00
# consume_top_time_last_6_month            1.200000e+01        19.00
# cross_consume_count_last_1_month         0.000000e+00         0.00
# trans_fail_top_count_enum_last_1_month   0.000000e+00         1.00
# trans_fail_top_count_enum_last_6_month   1.000000e+00         2.00
# trans_fail_top_count_enum_last_12_month  2.000000e+00         2.00
# consume_mini_time_last_1_month           0.000000e+00         0.00
# max_consume_count_later_6_month          3.000000e+00         6.00
# railway_consume_count_last_12_month      0.000000e+00         0.00
# jewelry_consume_count_last_6_month       0.000000e+00         0.00
# first_transaction_day                    9.880000e+02       997.00
# trans_day_last_12_month                  8.200000e+01        83.00
# apply_score                              5.430000e+02       656.00
# apply_credibility                        8.100000e+01        78.00
# query_org_count                          1.000000e+01        17.00
# query_finance_count                      7.000000e+00         5.00
# query_cash_count                         2.000000e+00         5.00
# query_sum_count                          1.300000e+01        22.00
# latest_one_month_apply                   2.000000e+00         6.00
# latest_three_month_apply                 1.000000e+01        11.00
# latest_six_month_apply                   1.300000e+01        12.00
# loans_score                              5.120000e+02       635.00
# loans_credibility_behavior               7.600000e+01        76.00
# loans_count                              3.200000e+01        68.00
# loans_settle_count                       3.200000e+01        67.00
# loans_overdue_count                      4.000000e+00         0.00
# loans_org_count_behavior                 8.000000e+00        26.00
# consfin_org_count_behavior               5.000000e+00        10.00
# loans_cash_count                         3.000000e+00        16.00
# latest_one_month_loan                    1.000000e+00         0.00
# latest_three_month_loan                  1.000000e+00         3.00
# latest_six_month_loan                    8.000000e+00        17.00
# history_suc_fee                          4.200000e+01        81.00
# history_fail_fee                         2.000000e+00         9.00
# latest_one_month_suc                     2.000000e+00         2.00
# latest_one_month_fail                    0.000000e+00         0.00
# loans_long_time                          3.590000e+02       352.00
# loans_credit_limit                       2.600000e+03      2100.00
# loans_credibility_limit                  7.300000e+01        75.00
# loans_org_count_current                  3.000000e+00        16.00
# loans_product_count                      3.000000e+00        17.00
# loans_max_limit                          3.000000e+03      5400.00
# loans_avg_limit                          1.900000e+03      1887.00
# consfin_credit_limit                     9.100000e+03      6700.00
# consfin_credibility                      8.000000e+01        78.00
# consfin_org_count_current                5.000000e+00        10.00
# consfin_product_count                    5.000000e+00        11.00
# consfin_max_limit                        1.800000e+04     13200.00
# consfin_avg_limit                        7.300000e+03      6640.00
# latest_query_day                         2.400000e+01        23.00
# loans_latest_day                         6.000000e+00        42.00
#
#                                                  2251
# low_volume_percent                       0.000000e+00
# middle_volume_percent                    8.000000e-01
# trans_amount_increase_rate_lately        1.100000e+00
# trans_activity_month                     9.400000e-01
# trans_activity_day                       7.270000e-01
# transd_mcc                               2.500000e+01
# trans_days_interval_filter               7.000000e+00
# trans_days_interval                      6.000000e+00
# regional_mobility                        3.000000e+00
# student_feature                          1.000000e+00
# number_of_trans_from_2011                3.100000e+01
# first_transaction_time                   2.014090e+07
# historical_trans_day                     4.670000e+02
# rank_trad_1_month                        2.500000e-01
# avg_consume_less_12_valid_month          7.000000e+00
# top_trans_count_last_1_month             5.000000e-02
# avg_price_top_last_12_valid_month        4.000000e-01
# trans_top_time_last_1_month              6.000000e+00
# trans_top_time_last_6_month              7.000000e+00
# consume_top_time_last_1_month            6.000000e+00
# consume_top_time_last_6_month            7.000000e+00
# cross_consume_count_last_1_month         0.000000e+00
# trans_fail_top_count_enum_last_1_month   5.000000e+00
# trans_fail_top_count_enum_last_6_month   8.000000e+00
# trans_fail_top_count_enum_last_12_month  8.000000e+00
# consume_mini_time_last_1_month           1.475926e+06
# max_consume_count_later_6_month          6.000000e+00
# railway_consume_count_last_12_month      0.000000e+00
# jewelry_consume_count_last_6_month       0.000000e+00
# first_transaction_day                    1.357000e+03
# trans_day_last_12_month                  8.500000e+01
# apply_score                              5.290000e+02
# apply_credibility                        7.900000e+01
# query_org_count                          1.200000e+01
# query_finance_count                      6.000000e+00
# query_cash_count                         4.000000e+00
# query_sum_count                          1.600000e+01
# latest_one_month_apply                   5.000000e+00
# latest_three_month_apply                 9.000000e+00
# latest_six_month_apply                   1.300000e+01
# loans_score                              4.760000e+02
# loans_credibility_behavior               7.600000e+01
# loans_count                              8.900000e+01
# loans_settle_count                       7.000000e+01
# loans_overdue_count                      5.000000e+00
# loans_org_count_behavior                 2.600000e+01
# consfin_org_count_behavior               1.000000e+01
# loans_cash_count                         1.600000e+01
# latest_one_month_loan                    1.000000e+00
# latest_three_month_loan                  2.000000e+00
# latest_six_month_loan                    3.400000e+01
# history_suc_fee                          9.600000e+01
# history_fail_fee                         4.800000e+01
# latest_one_month_suc                     0.000000e+00
# latest_one_month_fail                    1.000000e+00
# loans_long_time                          3.560000e+02
# loans_credit_limit                       2.500000e+03
# loans_credibility_limit                  7.600000e+01
# loans_org_count_current                  1.600000e+01
# loans_product_count                      1.700000e+01
# loans_max_limit                          6.000000e+03
# loans_avg_limit                          2.387000e+03
# consfin_credit_limit                     6.800000e+03
# consfin_credibility                      7.800000e+01
# consfin_org_count_current                1.000000e+01
# consfin_product_count                    1.200000e+01
# consfin_max_limit                        2.280000e+04
# consfin_avg_limit                        7.480000e+03
# latest_query_day                         1.000000e+01
# loans_latest_day                         1.900000e+01

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3327 entries, 110 to 1274
# Data columns (total 89 columns):
# custid                                        3327 non-null int64
# trade_no                                      3327 non-null object
# bank_card_no                                  3327 non-null object
# low_volume_percent                            3325 non-null float64
# middle_volume_percent                         3325 non-null float64
# take_amount_in_later_12_month_highest         3327 non-null int64
# trans_amount_increase_rate_lately             3325 non-null float64
# trans_activity_month                          3325 non-null float64
# trans_activity_day                            3325 non-null float64
# transd_mcc                                    3325 non-null float64
# trans_days_interval_filter                    3321 non-null float64
# trans_days_interval                           3325 non-null float64
# regional_mobility                             3325 non-null float64
# student_feature                               1208 non-null float64
# repayment_capability                          3327 non-null int64
# is_high_user                                  3327 non-null int64
# number_of_trans_from_2011                     3325 non-null float64
# first_transaction_time                        3325 non-null float64
# historical_trans_amount                       3327 non-null int64
# historical_trans_day                          3325 non-null float64
# rank_trad_1_month                             3325 non-null float64
# trans_amount_3_month                          3327 non-null int64
# avg_consume_less_12_valid_month               3325 non-null float64
# abs                                           3327 non-null int64
# top_trans_count_last_1_month                  3325 non-null float64
# avg_price_last_12_month                       3327 non-null int64
# avg_price_top_last_12_valid_month             3249 non-null float64
# reg_preference_for_trad                       3325 non-null object
# trans_top_time_last_1_month                   3321 non-null float64
# trans_top_time_last_6_month                   3321 non-null float64
# consume_top_time_last_1_month                 3321 non-null float64
# consume_top_time_last_6_month                 3321 non-null float64
# cross_consume_count_last_1_month              3037 non-null float64
# trans_fail_top_count_enum_last_1_month        3314 non-null float64
# trans_fail_top_count_enum_last_6_month        3314 non-null float64
# trans_fail_top_count_enum_last_12_month       3314 non-null float64
# consume_mini_time_last_1_month                3312 non-null float64
# max_cumulative_consume_later_1_month          3327 non-null int64
# max_consume_count_later_6_month               3321 non-null float64
# railway_consume_count_last_12_month           3319 non-null float64
# pawns_auctions_trusts_consume_last_1_month    3327 non-null int64
# pawns_auctions_trusts_consume_last_6_month    3327 non-null int64
# jewelry_consume_count_last_6_month            3319 non-null float64
# status                                        3327 non-null int64
# source                                        3327 non-null object
# first_transaction_day                         3325 non-null float64
# trans_day_last_12_month                       3325 non-null float64
# id_name                                       3125 non-null object
# apply_score                                   3107 non-null float64
# apply_credibility                             3107 non-null float64
# query_org_count                               3107 non-null float64
# query_finance_count                           3107 non-null float64
# query_cash_count                              3107 non-null float64
# query_sum_count                               3107 non-null float64
# latest_query_time                             3107 non-null object
# latest_one_month_apply                        3107 non-null float64
# latest_three_month_apply                      3107 non-null float64
# latest_six_month_apply                        3107 non-null float64
# loans_score                                   3112 non-null float64
# loans_credibility_behavior                    3112 non-null float64
# loans_count                                   3112 non-null float64
# loans_settle_count                            3112 non-null float64
# loans_overdue_count                           3112 non-null float64
# loans_org_count_behavior                      3112 non-null float64
# consfin_org_count_behavior                    3112 non-null float64
# loans_cash_count                              3112 non-null float64
# latest_one_month_loan                         3112 non-null float64
# latest_three_month_loan                       3112 non-null float64
# latest_six_month_loan                         3112 non-null float64
# history_suc_fee                               3112 non-null float64
# history_fail_fee                              3112 non-null float64
# latest_one_month_suc                          3112 non-null float64
# latest_one_month_fail                         3112 non-null float64
# loans_long_time                               3112 non-null float64
# loans_latest_time                             3112 non-null object
# loans_credit_limit                            3112 non-null float64
# loans_credibility_limit                       3112 non-null float64
# loans_org_count_current                       3112 non-null float64
# loans_product_count                           3112 non-null float64
# loans_max_limit                               3112 non-null float64
# loans_avg_limit                               3112 non-null float64
# consfin_credit_limit                          3112 non-null float64
# consfin_credibility                           3112 non-null float64
# consfin_org_count_current                     3112 non-null float64
# consfin_product_count                         3112 non-null float64
# consfin_max_limit                             3112 non-null float64
# consfin_avg_limit                             3112 non-null float64
# latest_query_day                              3107 non-null float64
# loans_latest_day                              3112 non-null float64
# dtypes: float64(70), int64(12), object(7)
# memory usage: 2.3+ MB

# %% [markdown]
# ## 数据描述

# %%
df_describe = train_set.describe().T

# %%
df_describe.head()
# Out:
#                                         count          mean           std  \
# custid                                 3327.0  1.685829e+06  1.039677e+06
# low_volume_percent                     3325.0  2.206316e-02  4.144446e-02
# middle_volume_percent                  3325.0  9.024331e-01  1.434408e-01
# take_amount_in_later_12_month_highest  3327.0  1.946736e+03  4.113834e+03
# trans_amount_increase_rate_lately      3325.0  1.906549e+01  8.297462e+02
#
#                                          min        25%         50%  \
# custid                                 114.0  754571.50  1623683.00
# low_volume_percent                       0.0       0.01        0.01
# middle_volume_percent                    0.0       0.88        0.96
# take_amount_in_later_12_month_highest    0.0       0.00      500.00
# trans_amount_increase_rate_lately        0.0       0.60        0.97
#
#                                               75%         max
# custid                                 2603724.00  4004694.00
# low_volume_percent                           0.02        1.00
# middle_volume_percent                        0.99        1.00
# take_amount_in_later_12_month_highest     2000.00    68000.00
# trans_amount_increase_rate_lately            1.62    47596.74

# %%
df_describe['max'].describe()
# Out:
# count    8.200000e+01
# mean     4.542959e+05
# std      2.325165e+06
# min      9.410000e-01
# 25%      2.475000e+01
# 50%      8.800000e+01
# 75%      8.522500e+02
# max      2.018011e+07
# Name: max, dtype: float64

# %%
df_describe['max'].hist(bins = 10)

# %%
df_describe['max'].min()
# Out:
# 0.941

# %%
# 最大值分布
max_distribution = pd.cut(df_describe['max'], 
                          bins=[0, 1.1, 10, 100, 1000, np.inf],
                          labels=['000-001', '001-010', '010-100', '100-1000', '1000+'])

# %%
max_distribution.value_counts().sort_index()
# Out:
# 000-001      9
# 001-010      3
# 010-100     32
# 100-1000    18
# 1000+       20
# Name: max, dtype: int64

# %%
max_distribution.head(10)
# Out:
# custid                                      1000+
# low_volume_percent                        000-001
# middle_volume_percent                     000-001
# take_amount_in_later_12_month_highest       1000+
# trans_amount_increase_rate_lately           1000+
# trans_activity_month                      000-001
# trans_activity_day                        000-001
# transd_mcc                                010-100
# trans_days_interval_filter               100-1000
# trans_days_interval                      100-1000
# Name: max, dtype: category
# Categories (5, object): [000-001 < 001-010 < 010-100 < 100-1000 < 1000+]

# %%
df_describe
# Out:
#                                              count          mean  \
# custid                                      3327.0  1.685829e+06
# low_volume_percent                          3325.0  2.206316e-02
# middle_volume_percent                       3325.0  9.024331e-01
# take_amount_in_later_12_month_highest       3327.0  1.946736e+03
# trans_amount_increase_rate_lately           3325.0  1.906549e+01
# trans_activity_month                        3325.0  8.068481e-01
# trans_activity_day                          3325.0  3.644478e-01
# transd_mcc                                  3325.0  1.744632e+01
# trans_days_interval_filter                  3321.0  2.898073e+01
# trans_days_interval                         3325.0  2.167850e+01
# regional_mobility                           3325.0  2.656842e+00
# student_feature                             1208.0  1.000828e+00
# repayment_capability                        3327.0  1.914114e+04
# is_high_user                                3327.0  1.172227e-02
# number_of_trans_from_2011                   3325.0  2.295850e+01
# first_transaction_time                      3325.0  2.015134e+07
# historical_trans_amount                     3327.0  2.265499e+05
# historical_trans_day                        3325.0  1.754662e+02
# rank_trad_1_month                           3325.0  4.786316e-01
# trans_amount_3_month                        3327.0  3.797162e+04
# avg_consume_less_12_valid_month             3325.0  6.566015e+00
# abs                                         3327.0  9.376375e+03
# top_trans_count_last_1_month                3325.0  3.594436e-01
# avg_price_last_12_month                     3327.0  1.224151e+03
# avg_price_top_last_12_valid_month           3249.0  5.162512e-01
# trans_top_time_last_1_month                 3321.0  7.119542e+00
# trans_top_time_last_6_month                 3321.0  2.007919e+01
# consume_top_time_last_1_month               3321.0  7.028907e+00
# consume_top_time_last_6_month               3321.0  2.068022e+01
# cross_consume_count_last_1_month            3037.0  6.269345e-01
# trans_fail_top_count_enum_last_1_month      3314.0  1.661436e+00
# trans_fail_top_count_enum_last_6_month      3314.0  4.589922e+00
# trans_fail_top_count_enum_last_12_month     3314.0  5.301147e+00
# consume_mini_time_last_1_month              3312.0  1.513977e+05
# max_cumulative_consume_later_1_month        3327.0  2.850207e+03
# max_consume_count_later_6_month             3321.0  6.090334e+00
# railway_consume_count_last_12_month         3319.0  3.253992e-02
# pawns_auctions_trusts_consume_last_1_month  3327.0  1.328389e+03
# pawns_auctions_trusts_consume_last_6_month  3327.0  1.859348e+04
# jewelry_consume_count_last_6_month          3319.0  1.506478e-02
# status                                      3327.0  2.506763e-01
# first_transaction_day                       3325.0  1.028795e+03
# trans_day_last_12_month                     3325.0  8.906977e+01
# apply_score                                 3107.0  5.768841e+02
# apply_credibility                           3107.0  7.600097e+01
# query_org_count                             3107.0  1.199002e+01
# query_finance_count                         3107.0  6.007403e+00
# query_cash_count                            3107.0  3.784680e+00
# query_sum_count                             3107.0  1.692790e+01
# latest_one_month_apply                      3107.0  4.347602e+00
# latest_three_month_apply                    3107.0  8.759575e+00
# latest_six_month_apply                      3107.0  1.236627e+01
# loans_score                                 3112.0  5.434753e+02
# loans_credibility_behavior                  3112.0  7.543284e+01
# loans_count                                 3112.0  3.589653e+01
# loans_settle_count                          3112.0  3.095630e+01
# loans_overdue_count                         3112.0  2.339974e+00
# loans_org_count_behavior                    3112.0  1.284672e+01
# consfin_org_count_behavior                  3112.0  4.716260e+00
# loans_cash_count                            3112.0  8.130463e+00
# latest_one_month_loan                       3112.0  9.633676e-01
# latest_three_month_loan                     3112.0  2.817802e+00
# latest_six_month_loan                       3112.0  1.390424e+01
# history_suc_fee                             3112.0  4.301703e+01
# history_fail_fee                            3112.0  1.756684e+01
# latest_one_month_suc                        3112.0  1.214332e+00
# latest_one_month_fail                       3112.0  1.326157e+00
# loans_long_time                             3112.0  3.354878e+02
# loans_credit_limit                          3112.0  2.088625e+03
# loans_credibility_limit                     3112.0  7.193348e+01
# loans_org_count_current                     3112.0  8.130463e+00
# loans_product_count                         3112.0  8.695373e+00
# loans_max_limit                             3112.0  3.386825e+03
# loans_avg_limit                             3112.0  1.818746e+03
# consfin_credit_limit                        3112.0  9.186279e+03
# consfin_credibility                         3112.0  7.624068e+01
# consfin_org_count_current                   3112.0  4.716260e+00
# consfin_product_count                       3112.0  5.200835e+00
# consfin_max_limit                           3112.0  1.608278e+04
# consfin_avg_limit                           3112.0  7.993420e+03
# latest_query_day                            3107.0  2.402028e+01
# loans_latest_day                            3112.0  5.557262e+01
#
#                                                      std           min  \
# custid                                      1.039677e+06  1.140000e+02
# low_volume_percent                          4.144446e-02  0.000000e+00
# middle_volume_percent                       1.434408e-01  0.000000e+00
# take_amount_in_later_12_month_highest       4.113834e+03  0.000000e+00
# trans_amount_increase_rate_lately           8.297462e+02  0.000000e+00
# trans_activity_month                        1.964616e-01  1.200000e-01
# trans_activity_day                          1.701654e-01  3.300000e-02
# transd_mcc                                  4.486967e+00  2.000000e+00
# trans_days_interval_filter                  2.231557e+01  0.000000e+00
# trans_days_interval                         1.643010e+01  5.000000e+00
# regional_mobility                           8.877182e-01  1.000000e+00
# student_feature                             2.877177e-02  1.000000e+00
# repayment_capability                        5.854450e+04  0.000000e+00
# is_high_user                                1.076492e-01  0.000000e+00
# number_of_trans_from_2011                   1.006304e+01  2.000000e+00
# first_transaction_time                      1.470414e+04  2.011010e+07
# historical_trans_amount                     2.429523e+05  0.000000e+00
# historical_trans_day                        9.965845e+01  5.000000e+00
# rank_trad_1_month                           2.647111e-01  5.000000e-02
# trans_amount_3_month                        5.669435e+04  0.000000e+00
# avg_consume_less_12_valid_month             1.376566e+00  0.000000e+00
# abs                                         2.870614e+04  0.000000e+00
# top_trans_count_last_1_month                3.525664e-01  5.000000e-02
# avg_price_last_12_month                     6.745982e+02  0.000000e+00
# avg_price_top_last_12_valid_month           1.006398e-01  5.000000e-02
# trans_top_time_last_1_month                 5.353851e+00  0.000000e+00
# trans_top_time_last_6_month                 1.279244e+01  0.000000e+00
# consume_top_time_last_1_month               5.472693e+00  0.000000e+00
# consume_top_time_last_6_month               1.310574e+01  0.000000e+00
# cross_consume_count_last_1_month            2.173647e+00  0.000000e+00
# trans_fail_top_count_enum_last_1_month      1.942901e+00  0.000000e+00
# trans_fail_top_count_enum_last_6_month      4.728541e+00  0.000000e+00
# trans_fail_top_count_enum_last_12_month     5.028607e+00  0.000000e+00
# consume_mini_time_last_1_month              3.721811e+05  0.000000e+00
# max_cumulative_consume_later_1_month        1.099708e+04  0.000000e+00
# max_consume_count_later_6_month             6.060958e+00  0.000000e+00
# railway_consume_count_last_12_month         5.567509e-01  0.000000e+00
# pawns_auctions_trusts_consume_last_1_month  6.003329e+03  0.000000e+00
# pawns_auctions_trusts_consume_last_6_month  2.707870e+04  0.000000e+00
# jewelry_consume_count_last_6_month          2.135034e-01  0.000000e+00
# status                                      4.334676e-01  0.000000e+00
# first_transaction_day                       5.321326e+02  1.270000e+02
# trans_day_last_12_month                     1.893263e+01  8.200000e+01
# apply_score                                 5.116540e+01  4.500000e+02
# apply_credibility                           4.161153e+00  5.000000e+01
# query_org_count                             7.091362e+00  1.000000e+00
# query_finance_count                         3.805004e+00  0.000000e+00
# query_cash_count                            2.610652e+00  0.000000e+00
# query_sum_count                             1.136909e+01  1.000000e+00
# latest_one_month_apply                      4.550376e+00  0.000000e+00
# latest_three_month_apply                    7.544703e+00  0.000000e+00
# latest_six_month_apply                      9.262592e+00  0.000000e+00
# loans_score                                 6.085840e+01  4.240000e+02
# loans_credibility_behavior                  2.231677e+00  5.600000e+01
# loans_count                                 2.461242e+01  1.000000e+00
# loans_settle_count                          2.164338e+01  0.000000e+00
# loans_overdue_count                         3.206807e+00  0.000000e+00
# loans_org_count_behavior                    7.458831e+00  1.000000e+00
# consfin_org_count_behavior                  2.970034e+00  0.000000e+00
# loans_cash_count                            5.401913e+00  0.000000e+00
# latest_one_month_loan                       1.481030e+00  0.000000e+00
# latest_three_month_loan                     3.455354e+00  0.000000e+00
# latest_six_month_loan                       1.089218e+01  0.000000e+00
# history_suc_fee                             3.011260e+01  0.000000e+00
# history_fail_fee                            2.442480e+01  0.000000e+00
# latest_one_month_suc                        1.921310e+00  0.000000e+00
# latest_one_month_fail                       3.900562e+00  0.000000e+00
# loans_long_time                             3.500899e+01  6.700000e+01
# loans_credit_limit                          7.171225e+02  0.000000e+00
# loans_credibility_limit                     1.101063e+01  0.000000e+00
# loans_org_count_current                     5.401913e+00  0.000000e+00
# loans_product_count                         5.780881e+00  0.000000e+00
# loans_max_limit                             1.473032e+03  0.000000e+00
# loans_avg_limit                             5.909923e+02  0.000000e+00
# consfin_credit_limit                        7.266314e+03  0.000000e+00
# consfin_credibility                         1.398981e+01  0.000000e+00
# consfin_org_count_current                   2.970034e+00  0.000000e+00
# consfin_product_count                       3.398880e+00  0.000000e+00
# consfin_max_limit                           1.425369e+04  0.000000e+00
# consfin_avg_limit                           5.591837e+03  0.000000e+00
# latest_query_day                            3.730507e+01 -2.000000e+00
# loans_latest_day                            5.376493e+01 -2.000000e+00
#
#                                                     25%          50%  \
# custid                                        754571.50   1623683.00
# low_volume_percent                                 0.01         0.01
# middle_volume_percent                              0.88         0.96
# take_amount_in_later_12_month_highest              0.00       500.00
# trans_amount_increase_rate_lately                  0.60         0.97
# trans_activity_month                               0.67         0.86
# trans_activity_day                                 0.23         0.35
# transd_mcc                                        15.00        17.00
# trans_days_interval_filter                        16.00        24.00
# trans_days_interval                               12.00        17.00
# regional_mobility                                  2.00         3.00
# student_feature                                    1.00         1.00
# repayment_capability                            8680.00     12240.00
# is_high_user                                       0.00         0.00
# number_of_trans_from_2011                         16.00        21.00
# first_transaction_time                      20141022.00  20151115.00
# historical_trans_amount                        78165.00    159480.00
# historical_trans_day                             100.00       160.00
# rank_trad_1_month                                  0.30         0.45
# trans_amount_3_month                           11420.00     25020.00
# avg_consume_less_12_valid_month                    6.00         7.00
# abs                                             1255.00      3390.00
# top_trans_count_last_1_month                       0.10         0.20
# avg_price_last_12_month                          920.00      1140.00
# avg_price_top_last_12_valid_month                  0.45         0.50
# trans_top_time_last_1_month                        3.00         7.00
# trans_top_time_last_6_month                       12.00        17.00
# consume_top_time_last_1_month                      3.00         7.00
# consume_top_time_last_6_month                     12.00        18.00
# cross_consume_count_last_1_month                   0.00         0.00
# trans_fail_top_count_enum_last_1_month             0.00         1.00
# trans_fail_top_count_enum_last_6_month             2.00         3.00
# trans_fail_top_count_enum_last_12_month            2.00         4.00
# consume_mini_time_last_1_month                     0.00        22.00
# max_cumulative_consume_later_1_month             690.00      1530.00
# max_consume_count_later_6_month                    3.00         5.00
# railway_consume_count_last_12_month                0.00         0.00
# pawns_auctions_trusts_consume_last_1_month         0.00        60.00
# pawns_auctions_trusts_consume_last_6_month      5155.00     12360.00
# jewelry_consume_count_last_6_month                 0.00         0.00
# status                                             0.00         0.00
# first_transaction_day                            631.00       918.00
# trans_day_last_12_month                           82.00        83.00
# apply_score                                      535.00       549.00
# apply_credibility                                 74.00        76.00
# query_org_count                                    7.00        11.00
# query_finance_count                                3.00         5.00
# query_cash_count                                   2.00         3.00
# query_sum_count                                    9.00        15.00
# latest_one_month_apply                             1.00         3.00
# latest_three_month_apply                           3.00         7.00
# latest_six_month_apply                             6.00        10.00
# loans_score                                      493.00       511.00
# loans_credibility_behavior                        74.00        76.00
# loans_count                                       17.00        30.00
# loans_settle_count                                15.00        26.00
# loans_overdue_count                                0.00         1.00
# loans_org_count_behavior                           7.00        12.00
# consfin_org_count_behavior                         2.00         4.00
# loans_cash_count                                   4.00         7.00
# latest_one_month_loan                              0.00         0.00
# latest_three_month_loan                            0.00         2.00
# latest_six_month_loan                              6.00        11.00
# history_suc_fee                                   21.00        37.00
# history_fail_fee                                   3.00         9.00
# latest_one_month_suc                               0.00         0.00
# latest_one_month_fail                              0.00         0.00
# loans_long_time                                  330.00       349.00
# loans_credit_limit                              1700.00      2100.00
# loans_credibility_limit                           72.00        74.00
# loans_org_count_current                            4.00         7.00
# loans_product_count                                4.00         8.00
# loans_max_limit                                 2300.00      3100.00
# loans_avg_limit                                 1533.00      1800.00
# consfin_credit_limit                            4800.00      7700.00
# consfin_credibility                               77.00        79.00
# consfin_org_count_current                          2.00         4.00
# consfin_product_count                              3.00         5.00
# consfin_max_limit                               7800.00     13800.00
# consfin_avg_limit                               4741.50      7028.00
# latest_query_day                                   5.00        14.00
# loans_latest_day                                  10.00        36.00
#
#                                                      75%           max
# custid                                      2.603724e+06  4.004694e+06
# low_volume_percent                          2.000000e-02  1.000000e+00
# middle_volume_percent                       9.900000e-01  1.000000e+00
# take_amount_in_later_12_month_highest       2.000000e+03  6.800000e+04
# trans_amount_increase_rate_lately           1.620000e+00  4.759674e+04
# trans_activity_month                        1.000000e+00  1.000000e+00
# trans_activity_day                          4.770000e-01  9.410000e-01
# transd_mcc                                  2.000000e+01  4.100000e+01
# trans_days_interval_filter                  3.300000e+01  2.610000e+02
# trans_days_interval                         2.600000e+01  2.340000e+02
# regional_mobility                           3.000000e+00  5.000000e+00
# student_feature                             1.000000e+00  2.000000e+00
# repayment_capability                        1.769000e+04  2.459390e+06
# is_high_user                                0.000000e+00  1.000000e+00
# number_of_trans_from_2011                   2.900000e+01  8.500000e+01
# first_transaction_time                      2.016083e+07  2.018011e+07
# historical_trans_amount                     2.971700e+05  4.008300e+06
# historical_trans_day                        2.310000e+02  9.070000e+02
# rank_trad_1_month                           6.000000e-01  1.000000e+00
# trans_amount_3_month                        4.786000e+04  1.540890e+06
# avg_consume_less_12_valid_month             7.000000e+00  1.100000e+01
# abs                                         7.960000e+03  9.184500e+05
# top_trans_count_last_1_month                6.500000e-01  1.000000e+00
# avg_price_last_12_month                     1.390000e+03  1.412000e+04
# avg_price_top_last_12_valid_month           5.500000e-01  1.000000e+00
# trans_top_time_last_1_month                 1.000000e+01  2.700000e+01
# trans_top_time_last_6_month                 2.600000e+01  1.240000e+02
# consume_top_time_last_1_month               1.100000e+01  2.700000e+01
# consume_top_time_last_6_month               2.600000e+01  1.510000e+02
# cross_consume_count_last_1_month            1.000000e+00  6.900000e+01
# trans_fail_top_count_enum_last_1_month      2.000000e+00  3.000000e+01
# trans_fail_top_count_enum_last_6_month      6.000000e+00  1.200000e+02
# trans_fail_top_count_enum_last_12_month     6.000000e+00  1.200000e+02
# consume_mini_time_last_1_month              7.000575e+04  2.364791e+06
# max_cumulative_consume_later_1_month        2.750000e+03  4.960100e+05
# max_consume_count_later_6_month             7.000000e+00  1.470000e+02
# railway_consume_count_last_12_month         0.000000e+00  3.000000e+01
# pawns_auctions_trusts_consume_last_1_month  9.700000e+02  1.696700e+05
# pawns_auctions_trusts_consume_last_6_month  2.352500e+04  5.253600e+05
# jewelry_consume_count_last_6_month          0.000000e+00  6.000000e+00
# status                                      1.000000e+00  1.000000e+00
# first_transaction_day                       1.307000e+03  2.697000e+03
# trans_day_last_12_month                     8.700000e+01  3.280000e+02
# apply_score                                 6.290000e+02  6.870000e+02
# apply_credibility                           7.800000e+01  9.300000e+01
# query_org_count                             1.600000e+01  5.400000e+01
# query_finance_count                         8.000000e+00  2.400000e+01
# query_cash_count                            5.000000e+00  1.600000e+01
# query_sum_count                             2.300000e+01  9.800000e+01
# latest_one_month_apply                      6.000000e+00  3.800000e+01
# latest_three_month_apply                    1.200000e+01  6.800000e+01
# latest_six_month_apply                      1.700000e+01  7.900000e+01
# loans_score                                 6.030000e+02  6.880000e+02
# loans_credibility_behavior                  7.700000e+01  8.500000e+01
# loans_count                                 5.000000e+01  1.580000e+02
# loans_settle_count                          4.200000e+01  1.470000e+02
# loans_overdue_count                         3.000000e+00  2.400000e+01
# loans_org_count_behavior                    1.700000e+01  4.100000e+01
# consfin_org_count_behavior                  7.000000e+00  1.800000e+01
# loans_cash_count                            1.100000e+01  3.100000e+01
# latest_one_month_loan                       1.000000e+00  1.500000e+01
# latest_three_month_loan                     4.000000e+00  4.800000e+01
# latest_six_month_loan                       2.000000e+01  7.400000e+01
# history_suc_fee                             5.900000e+01  1.920000e+02
# history_fail_fee                            2.200000e+01  2.780000e+02
# latest_one_month_suc                        2.000000e+00  1.600000e+01
# latest_one_month_fail                       1.000000e+00  5.300000e+01
# loans_long_time                             3.560000e+02  3.600000e+02
# loans_credit_limit                          2.400000e+03  6.000000e+03
# loans_credibility_limit                     7.500000e+01  8.900000e+01
# loans_org_count_current                     1.100000e+01  3.100000e+01
# loans_product_count                         1.200000e+01  3.200000e+01
# loans_max_limit                             4.300000e+03  9.800000e+03
# loans_avg_limit                             2.100000e+03  5.600000e+03
# consfin_credit_limit                        1.170000e+04  8.710000e+04
# consfin_credibility                         8.000000e+01  8.700000e+01
# consfin_org_count_current                   7.000000e+00  1.800000e+01
# consfin_product_count                       7.000000e+00  2.000000e+01
# consfin_max_limit                           2.040000e+04  2.664000e+05
# consfin_avg_limit                           9.944000e+03  7.020000e+04
# latest_query_day                            2.300000e+01  3.590000e+02
# loans_latest_day                            9.225000e+01  3.230000e+02

# %% [markdown]
# # 特征工程

# %% [markdown]
# ## 特征预处理

# %% [markdown]
# 任务1：对数据进行探索和分析。时间：2天
#
# - 数据类型的分析
# - 无关特征删除
# - 数据类型转换
# - 缺失值处理
# - ……以及你能想到和借鉴的数据分析处理

# %%
train_set = train_set.copy()

# %%
status = train_set['status']
del train_set['status']
train_set['status'] = status

# %%
train_set.shape
# Out:
# (3327, 89)

# %%
for count, col in enumerate(train_set.columns):
    dtype = str(test_set[col].dtype)
    if dtype != 'object':
        col_min = test_set[col].min()
        col_max = test_set[col].max()
        print(f'{count:02d}  {col:45s}\t # [{dtype:6s} {col_min:,}-{col_max:,}]')
    else:
        print(f'{count:02d}  {col:45s}\t # [{dtype:10s}]')
        obj = train_set[col].value_counts().sort_index()
        print(obj.head(20))
    # break
# Out:
# 00  custid                                       	 # [int64  2,244-3,832,193]
# 01  trade_no                                     	 # [object    ]
# 20180504155023833000000381228411    1
# 20180504155028091000000381224030    1
# 20180504155044450000000381226734    1
# 20180504155102497000000381226963    1
# 20180504155115618000000381228989    1
# 20180504155123490000000381229583    1
# 20180504155137627000000021137291    1
# 20180504155148729000000381229819    1
# 20180504155203298000000381229942    1
# 20180504155222051000000381233794    1
# 20180504155252113000000381239311    1
# 20180504155302404000000021136451    1
# 20180504155316469000000021138909    1
# 20180504155319956000000021136626    1
# 20180504155336144000000381241426    1
# 20180504155358051000000381239140    1
# 20180504155405877000000381243585    1
# 20180504155409262000000381248182    1
# 20180504155429742000000381243911    1
# 20180504155442259000000381244085    1
# Name: trade_no, dtype: int64
# 02  bank_card_no                                 	 # [object    ]
# 卡号1    3327
# Name: bank_card_no, dtype: int64
# 03  low_volume_percent                           	 # [float64 0.0-1.0]
# 04  middle_volume_percent                        	 # [float64 0.0-1.0]
# 05  take_amount_in_later_12_month_highest        	 # [int64  0-29,300]
# 06  trans_amount_increase_rate_lately            	 # [float64 0.0-301.47]
# 07  trans_activity_month                         	 # [float64 0.14-1.0]
# 08  trans_activity_day                           	 # [float64 0.05-0.925]
# 09  transd_mcc                                   	 # [float64 2.0-42.0]
# 10  trans_days_interval_filter                   	 # [float64 0.0-285.0]
# 11  trans_days_interval                          	 # [float64 4.0-151.0]
# 12  regional_mobility                            	 # [float64 1.0-5.0]
# 13  student_feature                              	 # [float64 1.0-2.0]
# 14  repayment_capability                         	 # [int64  20-834,920]
# 15  is_high_user                                 	 # [int64  0-1]
# 16  number_of_trans_from_2011                    	 # [float64 1.0-69.0]
# 17  first_transaction_time                       	 # [float64 20,110,101.0-20,180,114.0]
# 18  historical_trans_amount                      	 # [int64  0-13,601,300]
# 19  historical_trans_day                         	 # [float64 2.0-684.0]
# 20  rank_trad_1_month                            	 # [float64 0.05-1.0]
# 21  trans_amount_3_month                         	 # [int64  0-6,024,100]
# 22  avg_consume_less_12_valid_month              	 # [float64 0.0-11.0]
# 23  abs                                          	 # [int64  0-299,920]
# 24  top_trans_count_last_1_month                 	 # [float64 0.05-1.0]
# 25  avg_price_last_12_month                      	 # [int64  0-23,140]
# 26  avg_price_top_last_12_valid_month            	 # [float64 0.05-1.0]
# 27  reg_preference_for_trad                      	 # [object    ]
# 一线城市    2380
# 三线城市     747
# 二线城市      92
# 其他城市       3
# 境外       103
# Name: reg_preference_for_trad, dtype: int64
# 28  trans_top_time_last_1_month                  	 # [float64 0.0-27.0]
# 29  trans_top_time_last_6_month                  	 # [float64 0.0-116.0]
# 30  consume_top_time_last_1_month                	 # [float64 0.0-27.0]
# 31  consume_top_time_last_6_month                	 # [float64 0.0-115.0]
# 32  cross_consume_count_last_1_month             	 # [float64 0.0-66.0]
# 33  trans_fail_top_count_enum_last_1_month       	 # [float64 0.0-21.0]
# 34  trans_fail_top_count_enum_last_6_month       	 # [float64 0.0-48.0]
# 35  trans_fail_top_count_enum_last_12_month      	 # [float64 0.0-48.0]
# 36  consume_mini_time_last_1_month               	 # [float64 0.0-2,392,316.0]
# 37  max_cumulative_consume_later_1_month         	 # [int64  0-345,280]
# 38  max_consume_count_later_6_month              	 # [float64 0.0-48.0]
# 39  railway_consume_count_last_12_month          	 # [float64 0.0-4.0]
# 40  pawns_auctions_trusts_consume_last_1_month   	 # [int64  0-238,380]
# 41  pawns_auctions_trusts_consume_last_6_month   	 # [int64  0-496,980]
# 42  jewelry_consume_count_last_6_month           	 # [float64 0.0-5.0]
# 43  source                                       	 # [object    ]
# xs    3327
# Name: source, dtype: int64
# 44  first_transaction_day                        	 # [float64 127.0-2,697.0]
# 45  trans_day_last_12_month                      	 # [float64 82.0-382.0]
# 46  id_name                                      	 # [object    ]
# 丁以仲    1
# 丁伟康    1
# 丁凯扬    1
# 丁利军    1
# 丁宗辉    1
# 丁建豪    1
# 丁开     1
# 丁振     1
# 丁春海    1
# 丁晓峰    1
# 丁杰伟    1
# 丁楠     1
# 丁磊     1
# 丁红     1
# 丁陈真    1
# 丁震中    1
# 万严安    1
# 万利月    1
# 万小兵    1
# 万建军    1
# Name: id_name, dtype: int64
# 47  apply_score                                  	 # [float64 484.0-683.0]
# 48  apply_credibility                            	 # [float64 50.0-93.0]
# 49  query_org_count                              	 # [float64 1.0-37.0]
# 50  query_finance_count                          	 # [float64 0.0-20.0]
# 51  query_cash_count                             	 # [float64 0.0-16.0]
# 52  query_sum_count                              	 # [float64 1.0-87.0]
# 53  latest_query_time                            	 # [object    ]
# 2017-05-13    1
# 2017-05-18    1
# 2017-05-22    1
# 2017-05-24    1
# 2017-06-02    1
# 2017-06-03    1
# 2017-07-04    1
# 2017-07-19    1
# 2017-07-27    1
# 2017-08-17    1
# 2017-08-18    2
# 2017-08-22    2
# 2017-08-24    1
# 2017-08-26    1
# 2017-08-27    1
# 2017-09-05    1
# 2017-09-13    1
# 2017-09-18    1
# 2017-09-22    1
# 2017-09-28    1
# Name: latest_query_time, dtype: int64
# 54  latest_one_month_apply                       	 # [float64 0.0-34.0]
# 55  latest_three_month_apply                     	 # [float64 0.0-75.0]
# 56  latest_six_month_apply                       	 # [float64 0.0-80.0]
# 57  loans_score                                  	 # [float64 413.0-680.0]
# 58  loans_credibility_behavior                   	 # [float64 57.0-85.0]
# 59  loans_count                                  	 # [float64 1.0-158.0]
# 60  loans_settle_count                           	 # [float64 0.0-154.0]
# 61  loans_overdue_count                          	 # [float64 0.0-25.0]
# 62  loans_org_count_behavior                     	 # [float64 1.0-40.0]
# 63  consfin_org_count_behavior                   	 # [float64 0.0-17.0]
# 64  loans_cash_count                             	 # [float64 0.0-29.0]
# 65  latest_one_month_loan                        	 # [float64 0.0-13.0]
# 66  latest_three_month_loan                      	 # [float64 0.0-52.0]
# 67  latest_six_month_loan                        	 # [float64 0.0-64.0]
# 68  history_suc_fee                              	 # [float64 0.0-254.0]
# 69  history_fail_fee                             	 # [float64 0.0-345.0]
# 70  latest_one_month_suc                         	 # [float64 0.0-20.0]
# 71  latest_one_month_fail                        	 # [float64 0.0-58.0]
# 72  loans_long_time                              	 # [float64 26.0-360.0]
# 73  loans_latest_time                            	 # [object    ]
# 2017-06-15    1
# 2017-07-14    1
# 2017-07-16    1
# 2017-08-02    1
# 2017-08-04    1
# 2017-08-05    1
# 2017-08-10    1
# 2017-08-22    1
# 2017-08-29    1
# 2017-09-02    1
# 2017-09-03    1
# 2017-09-07    1
# 2017-09-09    2
# 2017-09-10    1
# 2017-09-15    2
# 2017-09-17    1
# 2017-09-21    1
# 2017-09-22    1
# 2017-09-24    1
# 2017-09-25    1
# Name: loans_latest_time, dtype: int64
# 74  loans_credit_limit                           	 # [float64 0.0-6,900.0]
# 75  loans_credibility_limit                      	 # [float64 0.0-89.0]
# 76  loans_org_count_current                      	 # [float64 0.0-29.0]
# 77  loans_product_count                          	 # [float64 0.0-30.0]
# 78  loans_max_limit                              	 # [float64 0.0-10,000.0]
# 79  loans_avg_limit                              	 # [float64 0.0-6,900.0]
# 80  consfin_credit_limit                         	 # [float64 0.0-82,800.0]
# 81  consfin_credibility                          	 # [float64 0.0-87.0]
# 82  consfin_org_count_current                    	 # [float64 0.0-17.0]
# 83  consfin_product_count                        	 # [float64 0.0-20.0]
# 84  consfin_max_limit                            	 # [float64 0.0-152,400.0]
# 85  consfin_avg_limit                            	 # [float64 0.0-82,800.0]
# 86  latest_query_day                             	 # [float64 -2.0-360.0]
# 87  loans_latest_day                             	 # [float64 -2.0-313.0]
# 88  status                                       	 # [int64  0-1]

# %%
# def col_describe(col):
#     if test_set[col].dtype != 'object':
#         print(train_set[col].describe())
#         print('-'*30)
#     obj = train_set[col].value_counts().sort_index()
#     if obj.shape[0] > 10:
#         print(obj.iloc[[0,1,2,3,-4, -3,-2,-1]])
#     else:
#         print(obj)

# for col in test_set.columns[19:28]:
#     print(col)
#     print('-'*30)
#     col_describe(col)
#     print('-'*30 + '\n\n')

# %%
# test_set['reg_preference_for_trad'].replace(['境外', '一线城市', '二线城市', '三线城市', '其他城市'], [1,2,3,4,5])

# %% [markdown]
# ### cols_to_del

# %% [markdown]
#     [删除] 00  custid                                       	 # [删除] 顾客ID号 没有重复
#     [删除] 01  trade_no                                     	 # [删除] 交易号 没有重复(可能带有时间信息)
#     [删除] 02  bank_card_no                                 	 # [删除] 卡号均为1
#     [删除] 43  source                                       	 # [删除] 均为xs
#     [删除] 46  id_name                                      	 # [姓名    ]

# %%
cols_to_del = train_set.columns[[0,1,2,43,46]]
cols_to_del
# Out:
# Index(['custid', 'trade_no', 'bank_card_no', 'source', 'id_name'], dtype='object')

# %% [markdown]
# ### cols_0_to_1

# %% [markdown]
#
#
#     [0-1] 03  low_volume_percent                           	 # [float64 0.0-1.0]
#     [0-1] 04  middle_volume_percent                        	 # [float64 0.0-1.0]
#     [0-1] 07  trans_activity_month                         	 # [float64 0.14-1.0]
#     [0-1] 08  trans_activity_day                           	 # [float64 0.05-0.925]
#     [0-1] 20  rank_trad_1_month                            	 # [float64 0.05-1.0]
#     [0-1] 24  top_trans_count_last_1_month                 	 # [float64 0.05-1.0]
#     [0-1] 26  avg_price_top_last_12_valid_month            	 # [float64 0.05-1.0]

# %%
cols_0_to_1 = list(train_set.columns[[3,4,7,8,20,24,26]])
cols_0_to_1
# Out:
# ['low_volume_percent',
#  'middle_volume_percent',
#  'trans_activity_month',
#  'trans_activity_day',
#  'rank_trad_1_month',
#  'top_trans_count_last_1_month',
#  'avg_price_top_last_12_valid_month']

# %% [markdown]
# ### cols_catg

# %% [markdown]
#
#     [分类] 12  regional_mobility                            	 # [分类(有序) 1，2，3，4，5] 区域流动性
#     [分类] 13  student_feature                              	 # [分类 1,空, 2] 学生属性
#     [分类] 15  is_high_user                                 	 # [分类  0/1]
#     [分类] 27  reg_preference_for_trad                      	 # [object    ]
#               test_set['reg_preference_for_trad'].replace(
#                     ['境外', '一线城市', '二线城市', '三线城市', '其他城市'],
#                     [1,2,3,4,5])

# %%
cols_catg = list(train_set.columns[[12,13,15,27]])
cols_catg
# Out:
# ['regional_mobility',
#  'student_feature',
#  'is_high_user',
#  'reg_preference_for_trad']

# %% [markdown]
# ### cols_date

# %% [markdown]
#     [日期] 17  first_transaction_time                       	 # [date 格式 20170217.0] 第一次交易时间 20110101-20180114
#     [日期] 53  latest_query_time                            	 # [object  格式 2017-06-15 ]
#     [日期] 73  loans_latest_time                            	 # [object  格式 2017-06-15 ]

# %%
cols_date = train_set.columns[[17,53,73]]
cols_date
# Out:
# Index(['first_transaction_time', 'latest_query_time', 'loans_latest_time'], dtype='object')

# %% [markdown]
# ### cols_nums

# %% [markdown]
#     05  take_amount_in_later_12_month_highest        	 # [int64  0-29,300]
#     06  trans_amount_increase_rate_lately            	 # [float64 0.0-301.47]
#
#     09  transd_mcc                                   	 # [float64 2.0-42.0]
#     10  trans_days_interval_filter                   	 # [int 0.0-285.0]
#     11  trans_days_interval                          	 # [int 4.0-151.0]
#     14  repayment_capability                         	 # [int64  20-834,920]
#     16  number_of_trans_from_2011                    	 # [int 1.0-69.0]
#     18  historical_trans_amount                      	 # [int64  0-13,601,300]
#     19  historical_trans_day                         	 # [int64 2.0-684.0]
#     21  trans_amount_3_month                         	 # [int64  0-6,024,100]
#     22  avg_consume_less_12_valid_month              	 # [int64 0.0-11.0] 0,1,2,...,11
#     23  abs                                          	 # [int64  0-299,920]
#     25  avg_price_last_12_month                      	 # [int64  0-23,140]
#     28  trans_top_time_last_1_month                  	 # [float64 0.0-27.0]
#     29  trans_top_time_last_6_month                  	 # [float64 0.0-116.0]
#     30  consume_top_time_last_1_month                	 # [float64 0.0-27.0]
#     31  consume_top_time_last_6_month                	 # [float64 0.0-115.0]
#     32  cross_consume_count_last_1_month             	 # [float64 0.0-66.0]
#     33  trans_fail_top_count_enum_last_1_month       	 # [float64 0.0-21.0]
#     34  trans_fail_top_count_enum_last_6_month       	 # [float64 0.0-48.0]
#     35  trans_fail_top_count_enum_last_12_month      	 # [float64 0.0-48.0]
#     36  consume_mini_time_last_1_month               	 # [float64 0.0-2,392,316.0]
#     37  max_cumulative_consume_later_1_month         	 # [int64  0-345,280]
#     38  max_consume_count_later_6_month              	 # [float64 0.0-48.0]
#     39  railway_consume_count_last_12_month          	 # [float64 0.0-4.0]
#     40  pawns_auctions_trusts_consume_last_1_month   	 # [int64  0-238,380]
#     41  pawns_auctions_trusts_consume_last_6_month   	 # [int64  0-496,980]
#     42  jewelry_consume_count_last_6_month           	 # [float64 0.0-5.0]
#     44  first_transaction_day                        	 # [float64 127.0-2,697.0]
#     45  trans_day_last_12_month                      	 # [float64 82.0-382.0]
#     47  apply_score                                  	 # [float64 484.0-683.0]
#     48  apply_credibility                            	 # [float64 50.0-93.0]
#     49  query_org_count                              	 # [float64 1.0-37.0]
#     50  query_finance_count                          	 # [float64 0.0-20.0]
#     51  query_cash_count                             	 # [float64 0.0-16.0]
#     52  query_sum_count                              	 # [float64 1.0-87.0]
#     54  latest_one_month_apply                       	 # [float64 0.0-34.0]
#     55  latest_three_month_apply                     	 # [float64 0.0-75.0]
#     56  latest_six_month_apply                       	 # [float64 0.0-80.0]
#     57  loans_score                                  	 # [float64 413.0-680.0]
#     58  loans_credibility_behavior                   	 # [float64 57.0-85.0]
#     59  loans_count                                  	 # [float64 1.0-158.0]
#     60  loans_settle_count                           	 # [float64 0.0-154.0]
#     61  loans_overdue_count                          	 # [float64 0.0-25.0]
#     62  loans_org_count_behavior                     	 # [float64 1.0-40.0]
#     63  consfin_org_count_behavior                   	 # [float64 0.0-17.0]
#     64  loans_cash_count                             	 # [float64 0.0-29.0]
#     65  latest_one_month_loan                        	 # [float64 0.0-13.0]
#     66  latest_three_month_loan                      	 # [float64 0.0-52.0]
#     67  latest_six_month_loan                        	 # [float64 0.0-64.0]
#     68  history_suc_fee                              	 # [float64 0.0-254.0]
#     69  history_fail_fee                             	 # [float64 0.0-345.0]
#     70  latest_one_month_suc                         	 # [float64 0.0-20.0]
#     71  latest_one_month_fail                        	 # [float64 0.0-58.0]
#     72  loans_long_time                              	 # [float64 26.0-360.0]
#
#     74  loans_credit_limit                           	 # [float64 0.0-6,900.0]
#     75  loans_credibility_limit                      	 # [float64 0.0-89.0]
#     76  loans_org_count_current                      	 # [float64 0.0-29.0]
#     77  loans_product_count                          	 # [float64 0.0-30.0]
#     78  loans_max_limit                              	 # [float64 0.0-10,000.0]
#     79  loans_avg_limit                              	 # [float64 0.0-6,900.0]
#     80  consfin_credit_limit                         	 # [float64 0.0-82,800.0]
#     81  consfin_credibility                          	 # [float64 0.0-87.0]
#     82  consfin_org_count_current                    	 # [float64 0.0-17.0]
#     83  consfin_product_count                        	 # [float64 0.0-20.0]
#     84  consfin_max_limit                            	 # [float64 0.0-152,400.0]
#     85  consfin_avg_limit                            	 # [float64 0.0-82,800.0]
#     86  latest_query_day                             	 # [float64 -2.0-360.0]
#     87  loans_latest_day                             	 # [float64 -2.0-313.0]
#
#     [目标] 88  status                                       	 # [int64  0-1]

# %%
# cols_0_to_1, cols_catg, cols_date, cols_to_del

# %%
cols_others = []
for cols_list in (cols_0_to_1, cols_catg, cols_date, cols_to_del):
    cols_others.extend(list(cols_list))

# %%
cols_others.append('status')

# %%
len(cols_others)
# Out:
# 20

# %%
cols_nums = [col for col in train_set.columns if col not in cols_others]

# %%
len(train_set.columns)
# Out:
# 92

# %%
len(cols_nums)
# Out:
# 72

# %%
cols_nums
# Out:
# ['take_amount_in_later_12_month_highest',
#  'trans_amount_increase_rate_lately',
#  'transd_mcc',
#  'trans_days_interval_filter',
#  'trans_days_interval',
#  'repayment_capability',
#  'number_of_trans_from_2011',
#  'historical_trans_amount',
#  'historical_trans_day',
#  'trans_amount_3_month',
#  'avg_consume_less_12_valid_month',
#  'abs',
#  'avg_price_last_12_month',
#  'trans_top_time_last_1_month',
#  'trans_top_time_last_6_month',
#  'consume_top_time_last_1_month',
#  'consume_top_time_last_6_month',
#  'cross_consume_count_last_1_month',
#  'trans_fail_top_count_enum_last_1_month',
#  'trans_fail_top_count_enum_last_6_month',
#  'trans_fail_top_count_enum_last_12_month',
#  'consume_mini_time_last_1_month',
#  'max_cumulative_consume_later_1_month',
#  'max_consume_count_later_6_month',
#  'railway_consume_count_last_12_month',
#  'pawns_auctions_trusts_consume_last_1_month',
#  'pawns_auctions_trusts_consume_last_6_month',
#  'jewelry_consume_count_last_6_month',
#  'first_transaction_day',
#  'trans_day_last_12_month',
#  'apply_score',
#  'apply_credibility',
#  'query_org_count',
#  'query_finance_count',
#  'query_cash_count',
#  'query_sum_count',
#  'latest_one_month_apply',
#  'latest_three_month_apply',
#  'latest_six_month_apply',
#  'loans_score',
#  'loans_credibility_behavior',
#  'loans_count',
#  'loans_settle_count',
#  'loans_overdue_count',
#  'loans_org_count_behavior',
#  'consfin_org_count_behavior',
#  'loans_cash_count',
#  'latest_one_month_loan',
#  'latest_three_month_loan',
#  'latest_six_month_loan',
#  'history_suc_fee',
#  'history_fail_fee',
#  'latest_one_month_suc',
#  'latest_one_month_fail',
#  'loans_long_time',
#  'loans_credit_limit',
#  'loans_credibility_limit',
#  'loans_org_count_current',
#  'loans_product_count',
#  'loans_max_limit',
#  'loans_avg_limit',
#  'consfin_credit_limit',
#  'consfin_credibility',
#  'consfin_org_count_current',
#  'consfin_product_count',
#  'consfin_max_limit',
#  'consfin_avg_limit',
#  'latest_query_day',
#  'loans_latest_day',
#  'first_transaction_time_diff_day',
#  'latest_query_time_diff_day',
#  'loans_latest_time_diff_day']

# %% [markdown]
# ## 处理空值

# %%
obj = train_set.isnull().sum().sort_values(ascending=False)
obj[obj>0]
# Out:
# student_feature                            2119
# cross_consume_count_last_1_month            290
# query_finance_count                         220
# latest_three_month_apply                    220
# apply_score                                 220
# apply_credibility                           220
# query_org_count                             220
# query_cash_count                            220
# query_sum_count                             220
# latest_query_time                           220
# latest_one_month_apply                      220
# latest_six_month_apply                      220
# latest_query_day                            220
# loans_org_count_current                     215
# loans_settle_count                          215
# loans_latest_day                            215
# consfin_avg_limit                           215
# consfin_max_limit                           215
# consfin_product_count                       215
# loans_credibility_limit                     215
# consfin_credibility                         215
# consfin_credit_limit                        215
# loans_avg_limit                             215
# loans_max_limit                             215
# loans_product_count                         215
# loans_score                                 215
# loans_credibility_behavior                  215
# loans_count                                 215
# consfin_org_count_current                   215
# loans_overdue_count                         215
# history_suc_fee                             215
# loans_credit_limit                          215
# loans_org_count_behavior                    215
# loans_long_time                             215
# latest_one_month_fail                       215
# latest_one_month_suc                        215
# history_fail_fee                            215
# loans_latest_time                           215
# latest_six_month_loan                       215
# latest_one_month_loan                       215
# loans_cash_count                            215
# consfin_org_count_behavior                  215
# latest_three_month_loan                     215
# id_name                                     202
# avg_price_top_last_12_valid_month            78
# consume_mini_time_last_1_month               15
# trans_fail_top_count_enum_last_1_month       13
# trans_fail_top_count_enum_last_6_month       13
# trans_fail_top_count_enum_last_12_month      13
# jewelry_consume_count_last_6_month            8
# railway_consume_count_last_12_month           8
# consume_top_time_last_6_month                 6
# consume_top_time_last_1_month                 6
# trans_top_time_last_1_month                   6
# max_consume_count_later_6_month               6
# trans_top_time_last_6_month                   6
# trans_days_interval_filter                    6
# rank_trad_1_month                             2
# historical_trans_day                          2
# number_of_trans_from_2011                     2
# trans_activity_day                            2
# first_transaction_time                        2
# transd_mcc                                    2
# avg_consume_less_12_valid_month               2
# trans_activity_month                          2
# first_transaction_day                         2
# trans_amount_increase_rate_lately             2
# top_trans_count_last_1_month                  2
# reg_preference_for_trad                       2
# middle_volume_percent                         2
# low_volume_percent                            2
# trans_day_last_12_month                       2
# trans_days_interval                           2
# regional_mobility                             2
# dtype: int64

# %% [markdown]
# ### 删除2行缺失较多的行

# %%
cond = train_set['first_transaction_day'].isnull()
train_set[cond].T
# Out:
#                                                                         2703  \
# custid                                                               2346029
# trade_no                                    20180507122903344000000023090358
# bank_card_no                                                             卡号1
# low_volume_percent                                                       NaN
# middle_volume_percent                                                    NaN
# take_amount_in_later_12_month_highest                                      0
# trans_amount_increase_rate_lately                                        NaN
# trans_activity_month                                                     NaN
# trans_activity_day                                                       NaN
# transd_mcc                                                               NaN
# trans_days_interval_filter                                               NaN
# trans_days_interval                                                      NaN
# regional_mobility                                                        NaN
# student_feature                                                          NaN
# repayment_capability                                                       0
# is_high_user                                                               0
# number_of_trans_from_2011                                                NaN
# first_transaction_time                                                   NaN
# historical_trans_amount                                                    0
# historical_trans_day                                                     NaN
# rank_trad_1_month                                                        NaN
# trans_amount_3_month                                                       0
# avg_consume_less_12_valid_month                                          NaN
# abs                                                                        0
# top_trans_count_last_1_month                                             NaN
# avg_price_last_12_month                                                    0
# avg_price_top_last_12_valid_month                                        NaN
# reg_preference_for_trad                                                  NaN
# trans_top_time_last_1_month                                              NaN
# trans_top_time_last_6_month                                              NaN
# consume_top_time_last_1_month                                            NaN
# consume_top_time_last_6_month                                            NaN
# cross_consume_count_last_1_month                                         NaN
# trans_fail_top_count_enum_last_1_month                                   NaN
# trans_fail_top_count_enum_last_6_month                                   NaN
# trans_fail_top_count_enum_last_12_month                                  NaN
# consume_mini_time_last_1_month                                           NaN
# max_cumulative_consume_later_1_month                                       0
# max_consume_count_later_6_month                                          NaN
# railway_consume_count_last_12_month                                      NaN
# pawns_auctions_trusts_consume_last_1_month                                 0
# pawns_auctions_trusts_consume_last_6_month                                 0
# jewelry_consume_count_last_6_month                                       NaN
# source                                                                    xs
# first_transaction_day                                                    NaN
# trans_day_last_12_month                                                  NaN
# id_name                                                                   周凤
# apply_score                                                              540
# apply_credibility                                                         78
# query_org_count                                                           17
# query_finance_count                                                        8
# query_cash_count                                                           8
# query_sum_count                                                           22
# latest_query_time                                                 2018-05-04
# latest_one_month_apply                                                     3
# latest_three_month_apply                                                   5
# latest_six_month_apply                                                    13
# loans_score                                                              488
# loans_credibility_behavior                                                75
# loans_count                                                               95
# loans_settle_count                                                        89
# loans_overdue_count                                                        5
# loans_org_count_behavior                                                  32
# consfin_org_count_behavior                                                 6
# loans_cash_count                                                          26
# latest_one_month_loan                                                      0
# latest_three_month_loan                                                    0
# latest_six_month_loan                                                     46
# history_suc_fee                                                          103
# history_fail_fee                                                          27
# latest_one_month_suc                                                       0
# latest_one_month_fail                                                      0
# loans_long_time                                                          352
# loans_latest_time                                                 2018-01-18
# loans_credit_limit                                                      1800
# loans_credibility_limit                                                   75
# loans_org_count_current                                                   26
# loans_product_count                                                       26
# loans_max_limit                                                         5000
# loans_avg_limit                                                         1684
# consfin_credit_limit                                                    8800
# consfin_credibility                                                       77
# consfin_org_count_current                                                  6
# consfin_product_count                                                      7
# consfin_max_limit                                                      19200
# consfin_avg_limit                                                       6150
# latest_query_day                                                           3
# loans_latest_day                                                         109
# status                                                                     0
#
#                                                                         3740
# custid                                                               2123079
# trade_no                                    20180507123543218000000023096586
# bank_card_no                                                             卡号1
# low_volume_percent                                                       NaN
# middle_volume_percent                                                    NaN
# take_amount_in_later_12_month_highest                                      0
# trans_amount_increase_rate_lately                                        NaN
# trans_activity_month                                                     NaN
# trans_activity_day                                                       NaN
# transd_mcc                                                               NaN
# trans_days_interval_filter                                               NaN
# trans_days_interval                                                      NaN
# regional_mobility                                                        NaN
# student_feature                                                          NaN
# repayment_capability                                                       0
# is_high_user                                                               0
# number_of_trans_from_2011                                                NaN
# first_transaction_time                                                   NaN
# historical_trans_amount                                                    0
# historical_trans_day                                                     NaN
# rank_trad_1_month                                                        NaN
# trans_amount_3_month                                                       0
# avg_consume_less_12_valid_month                                          NaN
# abs                                                                        0
# top_trans_count_last_1_month                                             NaN
# avg_price_last_12_month                                                    0
# avg_price_top_last_12_valid_month                                        NaN
# reg_preference_for_trad                                                  NaN
# trans_top_time_last_1_month                                              NaN
# trans_top_time_last_6_month                                              NaN
# consume_top_time_last_1_month                                            NaN
# consume_top_time_last_6_month                                            NaN
# cross_consume_count_last_1_month                                         NaN
# trans_fail_top_count_enum_last_1_month                                   NaN
# trans_fail_top_count_enum_last_6_month                                   NaN
# trans_fail_top_count_enum_last_12_month                                  NaN
# consume_mini_time_last_1_month                                           NaN
# max_cumulative_consume_later_1_month                                       0
# max_consume_count_later_6_month                                          NaN
# railway_consume_count_last_12_month                                      NaN
# pawns_auctions_trusts_consume_last_1_month                                 0
# pawns_auctions_trusts_consume_last_6_month                                 0
# jewelry_consume_count_last_6_month                                       NaN
# source                                                                    xs
# first_transaction_day                                                    NaN
# trans_day_last_12_month                                                  NaN
# id_name                                                                  潘朝婕
# apply_score                                                              534
# apply_credibility                                                         74
# query_org_count                                                            6
# query_finance_count                                                        3
# query_cash_count                                                           2
# query_sum_count                                                            8
# latest_query_time                                                 2018-04-06
# latest_one_month_apply                                                     0
# latest_three_month_apply                                                   3
# latest_six_month_apply                                                     5
# loans_score                                                              511
# loans_credibility_behavior                                                76
# loans_count                                                               17
# loans_settle_count                                                        15
# loans_overdue_count                                                        1
# loans_org_count_behavior                                                  10
# consfin_org_count_behavior                                                 6
# loans_cash_count                                                           4
# latest_one_month_loan                                                      0
# latest_three_month_loan                                                    2
# latest_six_month_loan                                                     10
# history_suc_fee                                                           26
# history_fail_fee                                                           8
# latest_one_month_suc                                                       0
# latest_one_month_fail                                                      0
# loans_long_time                                                          300
# loans_latest_time                                                 2018-03-17
# loans_credit_limit                                                      1200
# loans_credibility_limit                                                   71
# loans_org_count_current                                                    4
# loans_product_count                                                        4
# loans_max_limit                                                         1800
# loans_avg_limit                                                         1225
# consfin_credit_limit                                                    7000
# consfin_credibility                                                       78
# consfin_org_count_current                                                  6
# consfin_product_count                                                      6
# consfin_max_limit                                                      13800
# consfin_avg_limit                                                       8166
# latest_query_day                                                          31
# loans_latest_day                                                          51
# status                                                                     0

# %%
train_set = train_set[~cond].copy()

# %% [markdown]
# ### 分类类型缺失值处理
#
# student_feature缺失值处理

# %%
train_set['student_feature'].value_counts()
# Out:
# 1.0    1207
# 2.0       1
# Name: student_feature, dtype: int64

# %%
# 空值填充为0
train_set['student_feature'] = train_set['student_feature'].fillna(0).astype(int)

# %%
cols_catg
# Out:
# Index(['regional_mobility', 'student_feature', 'is_high_user',
#        'reg_preference_for_trad'],
#       dtype='object')

# %%
obj_null = train_set.isnull().sum()
obj_null[obj_null>0].head()
# Out:
# trans_days_interval_filter            4
# avg_price_top_last_12_valid_month    76
# trans_top_time_last_1_month           4
# trans_top_time_last_6_month           4
# consume_top_time_last_1_month         4
# dtype: int64

# %%
# 分类空值处理完毕
obj_null[cols_catg]
# Out:
# regional_mobility          0
# student_feature            0
# is_high_user               0
# reg_preference_for_trad    0
# dtype: int64

# %% [markdown]
# #### cols_catg

# %% [markdown]
#     [分类] 12  regional_mobility                                 # [分类(有序) 1，2，3，4，5] 区域流动性
#     [分类] 13  student_feature                                   # [分类 1,空, 2] 学生属性
#     [分类] 15  is_high_user                                      # [分类  0/1]
#     [分类] 27  reg_preference_for_trad                           # [object    ]
#               test_set['reg_preference_for_trad'].replace(
#                     ['境外', '一线城市', '二线城市', '三线城市', '其他城市'],
#                     [1,2,3,4,5])

# %%
cols_catg
# Out:
# Index(['regional_mobility', 'student_feature', 'is_high_user',
#        'reg_preference_for_trad'],
#       dtype='object')

# %% [markdown]
# reg_preference_for_trad

# %%
col = 'reg_preference_for_trad'
train_set[col] = train_set[col].replace(
                    ['境外', '一线城市', '二线城市', '三线城市', '其他城市'],
                    [1,2,3,4,5])

# %%
train_set[cols_catg].head()
# Out:
#       regional_mobility  student_feature  is_high_user  \
# 110                 1.0                1             0
# 3394                3.0                0             0
# 3052                2.0                0             0
# 490                 4.0                1             0
# 1                   4.0                1             0
#
#       reg_preference_for_trad
# 110                         2
# 3394                        2
# 3052                        2
# 490                         4
# 1                           2

# %% [markdown]
# regional_mobility

# %%
train_set.regional_mobility = train_set.regional_mobility.astype(int)

# %% [markdown]
# student_feature == 2 唯一一个

# %%
cond = train_set.student_feature > 1
train_set[cond].T
# Out:
#                                                                         2991
# custid                                                               2229219
# trade_no                                    20180507123630913000000388369982
# bank_card_no                                                             卡号1
# low_volume_percent                                                      0.02
# middle_volume_percent                                                   0.98
# take_amount_in_later_12_month_highest                                   2500
# trans_amount_increase_rate_lately                                       1.17
# trans_activity_month                                                     0.8
# trans_activity_day                                                     0.319
# transd_mcc                                                                21
# trans_days_interval_filter                                                26
# trans_days_interval                                                       15
# regional_mobility                                                          4
# student_feature                                                            2
# repayment_capability                                                   21020
# is_high_user                                                               0
# number_of_trans_from_2011                                                 35
# first_transaction_time                                           2.01407e+07
# historical_trans_amount                                                94690
# historical_trans_day                                                     181
# rank_trad_1_month                                                        0.3
# trans_amount_3_month                                                   16320
# avg_consume_less_12_valid_month                                            7
# abs                                                                     4180
# top_trans_count_last_1_month                                            0.15
# avg_price_last_12_month                                                 1050
# avg_price_top_last_12_valid_month                                       0.55
# reg_preference_for_trad                                                    2
# trans_top_time_last_1_month                                               11
# trans_top_time_last_6_month                                               12
# consume_top_time_last_1_month                                             11
# consume_top_time_last_6_month                                             17
# cross_consume_count_last_1_month                                           0
# trans_fail_top_count_enum_last_1_month                                     3
# trans_fail_top_count_enum_last_6_month                                     5
# trans_fail_top_count_enum_last_12_month                                    6
# consume_mini_time_last_1_month                                             0
# max_cumulative_consume_later_1_month                                    2060
# max_consume_count_later_6_month                                            3
# railway_consume_count_last_12_month                                        0
# pawns_auctions_trusts_consume_last_1_month                                 0
# pawns_auctions_trusts_consume_last_6_month                             12090
# jewelry_consume_count_last_6_month                                         0
# source                                                                    xs
# first_transaction_day                                                   1402
# trans_day_last_12_month                                                   82
# id_name                                                                   陈雷
# apply_score                                                              556
# apply_credibility                                                         74
# query_org_count                                                           23
# query_finance_count                                                       11
# query_cash_count                                                           8
# query_sum_count                                                           30
# latest_query_time                                                 2018-05-05
# latest_one_month_apply                                                    16
# latest_three_month_apply                                                  23
# latest_six_month_apply                                                    24
# loans_score                                                              518
# loans_credibility_behavior                                                74
# loans_count                                                               26
# loans_settle_count                                                        22
# loans_overdue_count                                                        2
# loans_org_count_behavior                                                  11
# consfin_org_count_behavior                                                 6
# loans_cash_count                                                           5
# latest_one_month_loan                                                      2
# latest_three_month_loan                                                    3
# latest_six_month_loan                                                      9
# history_suc_fee                                                           32
# history_fail_fee                                                          21
# latest_one_month_suc                                                       1
# latest_one_month_fail                                                      2
# loans_long_time                                                          357
# loans_latest_time                                                 2018-05-04
# loans_credit_limit                                                      1900
# loans_credibility_limit                                                   70
# loans_org_count_current                                                    5
# loans_product_count                                                        6
# loans_max_limit                                                         3500
# loans_avg_limit                                                         2000
# consfin_credit_limit                                                   13000
# consfin_credibility                                                       78
# consfin_org_count_current                                                  6
# consfin_product_count                                                      7
# consfin_max_limit                                                      21600
# consfin_avg_limit                                                      11200
# latest_query_day                                                           2
# loans_latest_day                                                           3
# status                                                                     1

# %%
# 转为0
train_set.loc[cond, 'student_feature'] = 0

# %%
for col in cols_catg:
    print(train_set[col].value_counts())
    print('-'*30 + '\n')
# Out:
# 3    1364
# 2    1076
# 4     535
# 1     325
# 5      25
# Name: regional_mobility, dtype: int64
# ------------------------------
#
# 0    2118
# 1    1207
# Name: student_feature, dtype: int64
# ------------------------------
#
# 0    3286
# 1      39
# Name: is_high_user, dtype: int64
# ------------------------------
#
# 2    2380
# 4     747
# 1     103
# 3      92
# 5       3
# Name: reg_preference_for_trad, dtype: int64
# ------------------------------

# %% [markdown]
# ### cols_date 日期型数据处理

# %%
cols_date
# Out:
# Index(['first_transaction_time', 'latest_query_time', 'loans_latest_time'], dtype='object')

# %%
train_set[cols_date].isnull().sum()
# Out:
# first_transaction_time      0
# latest_query_time         220
# loans_latest_time         215
# dtype: int64

# %%
train_set['first_transaction_time'].max()
# Out:
# 20180114.0

# %%
train_set['first_transaction_time'].head()
# Out:
# 110     20170217.0
# 3394    20170331.0
# 3052    20141110.0
# 490     20130817.0
# 1       20160402.0
# Name: first_transaction_time, dtype: float64

# %%
train_set['first_transaction_time'] = pd.to_datetime(train_set['first_transaction_time'].astype(int).astype(str))

# %%
for col in cols_date:
    train_set[col] = pd.to_datetime(train_set[col])

# %%
train_set[cols_date].isnull().sum()
# Out:
# first_transaction_time      0
# latest_query_time         220
# loans_latest_time         215
# dtype: int64

# %%
train_set[cols_date].min()
# Out:
# first_transaction_time   2011-01-01
# latest_query_time        2017-05-13
# loans_latest_time        2017-06-15
# dtype: datetime64[ns]

# %%
train_set[cols_date].max()
# Out:
# first_transaction_time   2018-01-14
# latest_query_time        2018-05-07
# loans_latest_time        2018-05-06
# dtype: datetime64[ns]

# %% [markdown]
# 时间取离2018-06-01相关的天数，空值取-999

# %%
cols_date_diff = [col+'_diff_day' for col in cols_date]
cols_date_diff
# Out:
# ['first_transaction_time_diff_day',
#  'latest_query_time_diff_day',
#  'loans_latest_time_diff_day']

# %%
train_set['first_transaction_time_diff_day']

# %%
for col, col_d in zip(cols_date_diff, cols_date):
    train_set[col] = ((pd.to_datetime('2018-06-01') - train_set[col_d])
                          .dt.days
                          .fillna(-999)
                          .astype(int))

# %%
train_set[cols_date_diff].head()
# Out:
#       first_transaction_time_diff_day  latest_query_time_diff_day  \
# 110                               469                          28
# 3394                              427                          55
# 3052                             1299                          28
# 490                              1749                          45
# 1                                 790                          29
#
#       loans_latest_time_diff_day
# 110                           37
# 3394                          52
# 3052                         162
# 490                           76
# 1                             27

# %%
train_set[cols_date_diff].isnull().sum()
# Out:
# first_transaction_time_diff_day    0
# latest_query_time_diff_day         0
# loans_latest_time_diff_day         0
# dtype: int64

# %% [markdown]
# ### cols_0_to_1

# %%
train_set[cols_0_to_1].isnull().sum()
# Out:
# low_volume_percent                    0
# middle_volume_percent                 0
# trans_activity_month                  0
# trans_activity_day                    0
# rank_trad_1_month                     0
# top_trans_count_last_1_month          0
# avg_price_top_last_12_valid_month    76
# dtype: int64

# %%
train_set['avg_price_top_last_12_valid_month'].describe()
# Out:
# count    3249.000000
# mean        0.516251
# std         0.100640
# min         0.050000
# 25%         0.450000
# 50%         0.500000
# 75%         0.550000
# max         1.000000
# Name: avg_price_top_last_12_valid_month, dtype: float64

# %%
train_set['avg_price_top_last_12_valid_month'] = train_set['avg_price_top_last_12_valid_month'].fillna(-1)

# %%
train_set[cols_0_to_1].isnull().sum()
# Out:
# low_volume_percent                   0
# middle_volume_percent                0
# trans_activity_month                 0
# trans_activity_day                   0
# rank_trad_1_month                    0
# top_trans_count_last_1_month         0
# avg_price_top_last_12_valid_month    0
# dtype: int64

# %% [markdown]
# ### cols_nums

# %%
print(cols_nums)
# Out:
# ['take_amount_in_later_12_month_highest', 'trans_amount_increase_rate_lately', 'transd_mcc', 'trans_days_interval_filter', 'trans_days_interval', 'repayment_capability', 'number_of_trans_from_2011', 'historical_trans_amount', 'historical_trans_day', 'trans_amount_3_month', 'avg_consume_less_12_valid_month', 'abs', 'avg_price_last_12_month', 'trans_top_time_last_1_month', 'trans_top_time_last_6_month', 'consume_top_time_last_1_month', 'consume_top_time_last_6_month', 'cross_consume_count_last_1_month', 'trans_fail_top_count_enum_last_1_month', 'trans_fail_top_count_enum_last_6_month', 'trans_fail_top_count_enum_last_12_month', 'consume_mini_time_last_1_month', 'max_cumulative_consume_later_1_month', 'max_consume_count_later_6_month', 'railway_consume_count_last_12_month', 'pawns_auctions_trusts_consume_last_1_month', 'pawns_auctions_trusts_consume_last_6_month', 'jewelry_consume_count_last_6_month', 'first_transaction_day', 'trans_day_last_12_month', 'apply_score', 'apply_credibility', 'query_org_count', 'query_finance_count', 'query_cash_count', 'query_sum_count', 'latest_one_month_apply', 'latest_three_month_apply', 'latest_six_month_apply', 'loans_score', 'loans_credibility_behavior', 'loans_count', 'loans_settle_count', 'loans_overdue_count', 'loans_org_count_behavior', 'consfin_org_count_behavior', 'loans_cash_count', 'latest_one_month_loan', 'latest_three_month_loan', 'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee', 'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time', 'loans_credit_limit', 'loans_credibility_limit', 'loans_org_count_current', 'loans_product_count', 'loans_max_limit', 'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility', 'consfin_org_count_current', 'consfin_product_count', 'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day', 'loans_latest_day', 'first_transaction_time_diff_day', 'latest_query_time_diff_day', 'loans_latest_time_diff_day']

# %%
obj = train_set[cols_nums].isnull().sum()
obj[obj>0]
# Out:
# trans_days_interval_filter                   4
# trans_top_time_last_1_month                  4
# trans_top_time_last_6_month                  4
# consume_top_time_last_1_month                4
# consume_top_time_last_6_month                4
# cross_consume_count_last_1_month           288
# trans_fail_top_count_enum_last_1_month      11
# trans_fail_top_count_enum_last_6_month      11
# trans_fail_top_count_enum_last_12_month     11
# consume_mini_time_last_1_month              13
# max_consume_count_later_6_month              4
# railway_consume_count_last_12_month          6
# jewelry_consume_count_last_6_month           6
# apply_score                                220
# apply_credibility                          220
# query_org_count                            220
# query_finance_count                        220
# query_cash_count                           220
# query_sum_count                            220
# latest_one_month_apply                     220
# latest_three_month_apply                   220
# latest_six_month_apply                     220
# loans_score                                215
# loans_credibility_behavior                 215
# loans_count                                215
# loans_settle_count                         215
# loans_overdue_count                        215
# loans_org_count_behavior                   215
# consfin_org_count_behavior                 215
# loans_cash_count                           215
# latest_one_month_loan                      215
# latest_three_month_loan                    215
# latest_six_month_loan                      215
# history_suc_fee                            215
# history_fail_fee                           215
# latest_one_month_suc                       215
# latest_one_month_fail                      215
# loans_long_time                            215
# loans_credit_limit                         215
# loans_credibility_limit                    215
# loans_org_count_current                    215
# loans_product_count                        215
# loans_max_limit                            215
# loans_avg_limit                            215
# consfin_credit_limit                       215
# consfin_credibility                        215
# consfin_org_count_current                  215
# consfin_product_count                      215
# consfin_max_limit                          215
# consfin_avg_limit                          215
# latest_query_day                           220
# loans_latest_day                           215
# dtype: int64

# %% [markdown]
# #### cols_nums_with_day

# %% [markdown]
# 天数相关的列

# %%
cols_nums_with_day = [col for col in obj[obj>0].index if 'day' in col]
cols_nums_with_day
# Out:
# ['trans_days_interval_filter', 'latest_query_day', 'loans_latest_day']

# %%
cols_date
# Out:
# Index(['first_transaction_time', 'latest_query_time', 'loans_latest_time'], dtype='object')

# %%
cols_date_diff
# Out:
# ['first_transaction_time_diff_day',
#  'latest_query_time_diff_day',
#  'loans_latest_time_diff_day']

# %%
cond = train_set['latest_query_day'].isnull()
train_set.loc[cond, cols_nums_with_day+cols_date_diff].head()
# Out:
#       trans_days_interval_filter  latest_query_day  loans_latest_day  \
# 4567                        52.0               NaN             162.0
# 3635                        20.0               NaN               NaN
# 3338                        26.0               NaN               NaN
# 1888                        28.0               NaN               NaN
# 876                         40.0               NaN               NaN
#
#       first_transaction_time_diff_day  latest_query_time_diff_day  \
# 4567                              901                        -999
# 3635                              393                        -999
# 3338                              793                        -999
# 1888                             1053                        -999
# 876                               693                        -999
#
#       loans_latest_time_diff_day
# 4567                         187
# 3635                        -999
# 3338                        -999
# 1888                        -999
# 876                         -999

# %% [markdown]
# 填充为-999

# %%
train_set[cols_nums_with_day] = train_set[cols_nums_with_day].fillna(-999)

# %% [markdown]
# #### 其余填充为中位数

# %%
obj = train_set[cols_nums].isnull().sum()
cols_nums_fillna = obj[obj>0].index

# %%
cols_nums_fillna
# Out:
# Index(['trans_top_time_last_1_month', 'trans_top_time_last_6_month',
#        'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
#        'cross_consume_count_last_1_month',
#        'trans_fail_top_count_enum_last_1_month',
#        'trans_fail_top_count_enum_last_6_month',
#        'trans_fail_top_count_enum_last_12_month',
#        'consume_mini_time_last_1_month', 'max_consume_count_later_6_month',
#        'railway_consume_count_last_12_month',
#        'jewelry_consume_count_last_6_month', 'apply_score',
#        'apply_credibility', 'query_org_count', 'query_finance_count',
#        'query_cash_count', 'query_sum_count', 'latest_one_month_apply',
#        'latest_three_month_apply', 'latest_six_month_apply', 'loans_score',
#        'loans_credibility_behavior', 'loans_count', 'loans_settle_count',
#        'loans_overdue_count', 'loans_org_count_behavior',
#        'consfin_org_count_behavior', 'loans_cash_count',
#        'latest_one_month_loan', 'latest_three_month_loan',
#        'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee',
#        'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
#        'loans_credit_limit', 'loans_credibility_limit',
#        'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
#        'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility',
#        'consfin_org_count_current', 'consfin_product_count',
#        'consfin_max_limit', 'consfin_avg_limit'],
#       dtype='object')

# %%
# 填充为中位数
for col in cols_nums_fillna:
    train_set[col] = train_set[col].fillna(train_set[col].median())

# %%
train_set.isnull().sum()
# Out:
# custid                                          0
# trade_no                                        0
# bank_card_no                                    0
# low_volume_percent                              0
# middle_volume_percent                           0
# take_amount_in_later_12_month_highest           0
# trans_amount_increase_rate_lately               0
# trans_activity_month                            0
# trans_activity_day                              0
# transd_mcc                                      0
# trans_days_interval_filter                      0
# trans_days_interval                             0
# regional_mobility                               0
# student_feature                                 0
# repayment_capability                            0
# is_high_user                                    0
# number_of_trans_from_2011                       0
# first_transaction_time                          0
# historical_trans_amount                         0
# historical_trans_day                            0
# rank_trad_1_month                               0
# trans_amount_3_month                            0
# avg_consume_less_12_valid_month                 0
# abs                                             0
# top_trans_count_last_1_month                    0
# avg_price_last_12_month                         0
# avg_price_top_last_12_valid_month               0
# reg_preference_for_trad                         0
# trans_top_time_last_1_month                     0
# trans_top_time_last_6_month                     0
# consume_top_time_last_1_month                   0
# consume_top_time_last_6_month                   0
# cross_consume_count_last_1_month                0
# trans_fail_top_count_enum_last_1_month          0
# trans_fail_top_count_enum_last_6_month          0
# trans_fail_top_count_enum_last_12_month         0
# consume_mini_time_last_1_month                  0
# max_cumulative_consume_later_1_month            0
# max_consume_count_later_6_month                 0
# railway_consume_count_last_12_month             0
# pawns_auctions_trusts_consume_last_1_month      0
# pawns_auctions_trusts_consume_last_6_month      0
# jewelry_consume_count_last_6_month              0
# source                                          0
# first_transaction_day                           0
# trans_day_last_12_month                         0
# id_name                                       202
# apply_score                                     0
# apply_credibility                               0
# query_org_count                                 0
# query_finance_count                             0
# query_cash_count                                0
# query_sum_count                                 0
# latest_query_time                             220
# latest_one_month_apply                          0
# latest_three_month_apply                        0
# latest_six_month_apply                          0
# loans_score                                     0
# loans_credibility_behavior                      0
# loans_count                                     0
# loans_settle_count                              0
# loans_overdue_count                             0
# loans_org_count_behavior                        0
# consfin_org_count_behavior                      0
# loans_cash_count                                0
# latest_one_month_loan                           0
# latest_three_month_loan                         0
# latest_six_month_loan                           0
# history_suc_fee                                 0
# history_fail_fee                                0
# latest_one_month_suc                            0
# latest_one_month_fail                           0
# loans_long_time                                 0
# loans_latest_time                             215
# loans_credit_limit                              0
# loans_credibility_limit                         0
# loans_org_count_current                         0
# loans_product_count                             0
# loans_max_limit                                 0
# loans_avg_limit                                 0
# consfin_credit_limit                            0
# consfin_credibility                             0
# consfin_org_count_current                       0
# consfin_product_count                           0
# consfin_max_limit                               0
# consfin_avg_limit                               0
# latest_query_day                                0
# loans_latest_day                                0
# status                                          0
# first_transaction_time_diff_day                 0
# latest_query_time_diff_day                      0
# loans_latest_time_diff_day                      0
# dtype: int64

# %% [markdown]
# # 特征权重

# %% [markdown]
# ## IV值

# %% [markdown]
# https://medium.com/@sundarstyles89/weight-of-evidence-and-information-value-using-python-6f05072e83eb
#
# Weight of evidence (WOE) and Information value (IV) are simple, yet powerful techniques to perform variable transformation and selection. These concepts have huge connection with the logistic regression modeling technique. It is widely used in credit scoring to measure the separation of good vs bad customers.
#
# [github_code](https://github.com/Sundar0989/WOE-and-IV?source=post_page---------------------------)

# %% [markdown]
# 调用他人写好的脚本

# %%
# import packages
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
train_set.columns
# Out:
# Index(['custid', 'trade_no', 'bank_card_no', 'low_volume_percent',
#        'middle_volume_percent', 'take_amount_in_later_12_month_highest',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'repayment_capability', 'is_high_user', 'number_of_trans_from_2011',
#        'first_transaction_time', 'historical_trans_amount',
#        'historical_trans_day', 'rank_trad_1_month', 'trans_amount_3_month',
#        'avg_consume_less_12_valid_month', 'abs',
#        'top_trans_count_last_1_month', 'avg_price_last_12_month',
#        'avg_price_top_last_12_valid_month', 'reg_preference_for_trad',
#        'trans_top_time_last_1_month', 'trans_top_time_last_6_month',
#        'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
#        'cross_consume_count_last_1_month',
#        'trans_fail_top_count_enum_last_1_month',
#        'trans_fail_top_count_enum_last_6_month',
#        'trans_fail_top_count_enum_last_12_month',
#        'consume_mini_time_last_1_month',
#        'max_cumulative_consume_later_1_month',
#        'max_consume_count_later_6_month',
#        'railway_consume_count_last_12_month',
#        'pawns_auctions_trusts_consume_last_1_month',
#        'pawns_auctions_trusts_consume_last_6_month',
#        'jewelry_consume_count_last_6_month', 'source', 'first_transaction_day',
#        'trans_day_last_12_month', 'id_name', 'apply_score',
#        'apply_credibility', 'query_org_count', 'query_finance_count',
#        'query_cash_count', 'query_sum_count', 'latest_query_time',
#        'latest_one_month_apply', 'latest_three_month_apply',
#        'latest_six_month_apply', 'loans_score', 'loans_credibility_behavior',
#        'loans_count', 'loans_settle_count', 'loans_overdue_count',
#        'loans_org_count_behavior', 'consfin_org_count_behavior',
#        'loans_cash_count', 'latest_one_month_loan', 'latest_three_month_loan',
#        'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee',
#        'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
#        'loans_latest_time', 'loans_credit_limit', 'loans_credibility_limit',
#        'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
#        'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility',
#        'consfin_org_count_current', 'consfin_product_count',
#        'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day',
#        'loans_latest_day', 'status', 'first_transaction_time_diff_day',
#        'latest_query_time_diff_day', 'loans_latest_time_diff_day'],
#       dtype='object')

# %%
final_iv
# Out:
#                                   VAR_NAME  MIN_VALUE   MAX_VALUE  COUNT  \
# 0                       low_volume_percent      0.000       0.010   1865
# 1                       low_volume_percent      0.020       0.020    638
# 2                       low_volume_percent      0.030       1.000    822
# 3                    middle_volume_percent      0.000       0.920   1143
# 4                    middle_volume_percent      0.930       0.980   1294
# 5                    middle_volume_percent      0.990       1.000    888
# 6                     trans_activity_month      0.120       0.860   1666
# 7                     trans_activity_month      0.870       1.000   1659
# 8                       trans_activity_day      0.033       0.272   1112
# 9                       trans_activity_day      0.273       0.430   1109
# 10                      trans_activity_day      0.433       0.941   1104
# 11                       rank_trad_1_month      0.050       0.200    576
# 12                       rank_trad_1_month      0.250       0.350    776
# 13                       rank_trad_1_month      0.400       0.450    535
# 14                       rank_trad_1_month      0.500       0.550    446
# 15                       rank_trad_1_month      0.600       0.750    466
# 16                       rank_trad_1_month      0.800       1.000    526
# 17            top_trans_count_last_1_month      0.050       0.100   1248
# 18            top_trans_count_last_1_month      0.150       0.400   1161
# 19            top_trans_count_last_1_month      0.650       1.000    916
# 20       avg_price_top_last_12_valid_month     -1.000       0.500   1972
# 21       avg_price_top_last_12_valid_month      0.550       1.000   1353
# 22                       regional_mobility      1.000       2.000   1401
# 23                       regional_mobility      3.000       3.000   1364
# 24                       regional_mobility      4.000       5.000    560
# 25                         student_feature      0.000       0.000   2118
# 26                         student_feature      1.000       1.000   1207
# 27                            is_high_user      0.000       0.000   3286
# 28                            is_high_user      1.000       1.000     39
# 29                 reg_preference_for_trad      1.000       2.000   2483
# 30                 reg_preference_for_trad      3.000       5.000    842
# 31         first_transaction_time_diff_day    138.000     929.000   1664
# 32         first_transaction_time_diff_day    930.000    2708.000   1661
# 33              latest_query_time_diff_day   -999.000      30.000    969
# 34              latest_query_time_diff_day     31.000      39.000    810
# 35              latest_query_time_diff_day     40.000      48.000    736
# 36              latest_query_time_diff_day     49.000     384.000    810
# 37              loans_latest_time_diff_day   -999.000      55.000   1681
# 38              loans_latest_time_diff_day     56.000     351.000   1644
# 39   take_amount_in_later_12_month_highest      0.000     500.000   1683
# 40   take_amount_in_later_12_month_highest    600.000   68000.000   1642
# 41       trans_amount_increase_rate_lately      0.000       0.970   1667
# 42       trans_amount_increase_rate_lately      0.980   47596.740   1658
# 43                              transd_mcc      2.000      17.000   1716
# 44                              transd_mcc     18.000      41.000   1609
# 45              trans_days_interval_filter   -999.000      24.000   1757
# 46              trans_days_interval_filter     25.000     261.000   1568
# 47                     trans_days_interval      5.000      10.000    605
# 48                     trans_days_interval     11.000      14.000    632
# 49                     trans_days_interval     15.000      17.000    426
# ..                                     ...        ...         ...    ...
# 199                     loans_credit_limit      0.000    1800.000   1033
# 200                     loans_credit_limit   1900.000    2100.000    930
# 201                     loans_credit_limit   2200.000    2400.000    612
# 202                     loans_credit_limit   2500.000    6000.000    750
# 203                loans_credibility_limit      0.000      74.000   2308
# 204                loans_credibility_limit     75.000      89.000   1017
# 205                loans_org_count_current      0.000       5.000   1199
# 206                loans_org_count_current      6.000       9.000   1032
# 207                loans_org_count_current     10.000      31.000   1094
# 208                    loans_product_count      0.000       6.000   1328
# 209                    loans_product_count      7.000      10.000    957
# 210                    loans_product_count     11.000      32.000   1040
# 211                        loans_max_limit      0.000    3100.000   1792
# 212                        loans_max_limit   3200.000    9800.000   1533
# 213                        loans_avg_limit      0.000    1655.000   1110
# 214                        loans_avg_limit   1657.000    1950.000   1107
# 215                        loans_avg_limit   1952.000    5600.000   1108
# 216                   consfin_credit_limit      0.000    5000.000    835
# 217                   consfin_credit_limit   5100.000    7700.000    956
# 218                   consfin_credit_limit   7800.000   11300.000    724
# 219                   consfin_credit_limit  11400.000   87100.000    810
# 220                    consfin_credibility      0.000      79.000   2187
# 221                    consfin_credibility     80.000      87.000   1138
# 222              consfin_org_count_current      0.000       1.000    431
# 223              consfin_org_count_current      2.000       3.000    816
# 224              consfin_org_count_current        NaN         NaN      0
# 225              consfin_org_count_current      4.000       4.000    605
# 226              consfin_org_count_current      5.000       5.000    354
# 227              consfin_org_count_current      6.000       6.000    310
# 228              consfin_org_count_current      7.000       8.000    454
# 229              consfin_org_count_current      9.000      18.000    355
# 230                  consfin_product_count      0.000       5.000   2036
# 231                  consfin_product_count      6.000      20.000   1289
# 232                      consfin_max_limit      0.000    7800.000    850
# 233                      consfin_max_limit   8100.000   13800.000    927
# 234                      consfin_max_limit  14100.000   20400.000    867
# 235                      consfin_max_limit  20700.000  266400.000    681
# 236                      consfin_avg_limit      0.000    3600.000    490
# 237                      consfin_avg_limit   3612.000    5250.000    463
# 238                      consfin_avg_limit   5255.000    6650.000    473
# 239                      consfin_avg_limit   6660.000    7400.000    480
# 240                      consfin_avg_limit   7425.000    9175.000    472
# 241                      consfin_avg_limit   9188.000   12000.000    476
# 242                      consfin_avg_limit  12020.000   70200.000    471
# 243                       latest_query_day   -999.000       4.000    899
# 244                       latest_query_day      5.000      13.000    814
# 245                       latest_query_day     14.000      23.000    843
# 246                       latest_query_day     24.000     359.000    769
# 247                       loans_latest_day   -999.000      29.000   1670
# 248                       loans_latest_day     30.000     323.000   1655
#
#      EVENT  EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0      442    0.236997      1423        0.763003    0.529976        0.571257
# 1      171    0.268025       467        0.731975    0.205036        0.187475
# 2      221    0.268856       601        0.731144    0.264988        0.241269
# 3      265    0.231846       878        0.768154    0.317746        0.352469
# 4      336    0.259660       958        0.740340    0.402878        0.384585
# 5      233    0.262387       655        0.737613    0.279376        0.262947
# 6      411    0.246699      1255        0.753301    0.492806        0.503814
# 7      423    0.254973      1236        0.745027    0.507194        0.496186
# 8      296    0.266187       816        0.733813    0.354916        0.327579
# 9      270    0.243463       839        0.756537    0.323741        0.336813
# 10     268    0.242754       836        0.757246    0.321343        0.335608
# 11     111    0.192708       465        0.807292    0.133094        0.186672
# 12     160    0.206186       616        0.793814    0.191847        0.247290
# 13     114    0.213084       421        0.786916    0.136691        0.169008
# 14     117    0.262332       329        0.737668    0.140288        0.132075
# 15     138    0.296137       328        0.703863    0.165468        0.131674
# 16     194    0.368821       332        0.631179    0.232614        0.133280
# 17     270    0.216346       978        0.783654    0.323741        0.392613
# 18     270    0.232558       891        0.767442    0.323741        0.357688
# 19     294    0.320961       622        0.679039    0.352518        0.249699
# 20     452    0.229209      1520        0.770791    0.541966        0.610197
# 21     382    0.282336       971        0.717664    0.458034        0.389803
# 22     369    0.263383      1032        0.736617    0.442446        0.414291
# 23     332    0.243402      1032        0.756598    0.398082        0.414291
# 24     133    0.237500       427        0.762500    0.159472        0.171417
# 25     524    0.247403      1594        0.752597    0.628297        0.639904
# 26     310    0.256835       897        0.743165    0.371703        0.360096
# 27     831    0.252891      2455        0.747109    0.996403        0.985548
# 28       3    0.076923        36        0.923077    0.003597        0.014452
# 29     627    0.252517      1856        0.747483    0.751799        0.745082
# 30     207    0.245843       635        0.754157    0.248201        0.254918
# 31     437    0.262620      1227        0.737380    0.523981        0.492573
# 32     397    0.239013      1264        0.760987    0.476019        0.507427
# 33     209    0.215686       760        0.784314    0.250600        0.305098
# 34     181    0.223457       629        0.776543    0.217026        0.252509
# 35     196    0.266304       540        0.733696    0.235012        0.216780
# 36     248    0.306173       562        0.693827    0.297362        0.225612
# 37     409    0.243308      1272        0.756692    0.490408        0.510638
# 38     425    0.258516      1219        0.741484    0.509592        0.489362
# 39     417    0.247772      1266        0.752228    0.500000        0.508230
# 40     417    0.253959      1225        0.746041    0.500000        0.491770
# 41     409    0.245351      1258        0.754649    0.490408        0.505018
# 42     425    0.256333      1233        0.743667    0.509592        0.494982
# 43     439    0.255828      1277        0.744172    0.526379        0.512646
# 44     395    0.245494      1214        0.754506    0.473621        0.487354
# 45     413    0.235060      1344        0.764940    0.495204        0.539542
# 46     421    0.268495      1147        0.731505    0.504796        0.460458
# 47     120    0.198347       485        0.801653    0.143885        0.194701
# 48     156    0.246835       476        0.753165    0.187050        0.191088
# 49     106    0.248826       320        0.751174    0.127098        0.128462
# ..     ...         ...       ...             ...         ...             ...
# 199    285    0.275895       748        0.724105    0.341727        0.300281
# 200    233    0.250538       697        0.749462    0.279376        0.279807
# 201    144    0.235294       468        0.764706    0.172662        0.187876
# 202    172    0.229333       578        0.770667    0.206235        0.232035
# 203    579    0.250867      1729        0.749133    0.694245        0.694099
# 204    255    0.250737       762        0.749263    0.305755        0.305901
# 205    280    0.233528       919        0.766472    0.335731        0.368928
# 206    250    0.242248       782        0.757752    0.299760        0.313930
# 207    304    0.277879       790        0.722121    0.364508        0.317142
# 208    312    0.234940      1016        0.765060    0.374101        0.407868
# 209    226    0.236155       731        0.763845    0.270983        0.293456
# 210    296    0.284615       744        0.715385    0.354916        0.298675
# 211    482    0.268973      1310        0.731027    0.577938        0.525893
# 212    352    0.229615      1181        0.770385    0.422062        0.474107
# 213    304    0.273874       806        0.726126    0.364508        0.323565
# 214    276    0.249322       831        0.750678    0.330935        0.333601
# 215    254    0.229242       854        0.770758    0.304556        0.342834
# 216    264    0.316168       571        0.683832    0.316547        0.229225
# 217    239    0.250000       717        0.750000    0.286571        0.287836
# 218    164    0.226519       560        0.773481    0.196643        0.224809
# 219    167    0.206173       643        0.793827    0.200240        0.258129
# 220    565    0.258345      1622        0.741655    0.677458        0.651144
# 221    269    0.236380       869        0.763620    0.322542        0.348856
# 222    115    0.266821       316        0.733179    0.137890        0.126857
# 223    184    0.225490       632        0.774510    0.220624        0.253713
# 224      0         NaN         0             NaN    0.000000        0.000000
# 225    144    0.238017       461        0.761983    0.172662        0.185066
# 226     82    0.231638       272        0.768362    0.098321        0.109193
# 227     68    0.219355       242        0.780645    0.081535        0.097150
# 228    131    0.288546       323        0.711454    0.157074        0.129667
# 229    110    0.309859       245        0.690141    0.131894        0.098354
# 230    479    0.235265      1557        0.764735    0.574341        0.625050
# 231    355    0.275407       934        0.724593    0.425659        0.374950
# 232    242    0.284706       608        0.715294    0.290168        0.244079
# 233    241    0.259978       686        0.740022    0.288969        0.275391
# 234    210    0.242215       657        0.757785    0.251799        0.263749
# 235    141    0.207048       540        0.792952    0.169065        0.216780
# 236    156    0.318367       334        0.681633    0.187050        0.134083
# 237    138    0.298056       325        0.701944    0.165468        0.130470
# 238    130    0.274841       343        0.725159    0.155875        0.137696
# 239    113    0.235417       367        0.764583    0.135492        0.147330
# 240    111    0.235169       361        0.764831    0.133094        0.144922
# 241    102    0.214286       374        0.785714    0.122302        0.150141
# 242     84    0.178344       387        0.821656    0.100719        0.155359
# 243    194    0.215795       705        0.784205    0.232614        0.283019
# 244    184    0.226044       630        0.773956    0.220624        0.252910
# 245    220    0.260973       623        0.739027    0.263789        0.250100
# 246    236    0.306892       533        0.693108    0.282974        0.213970
# 247    404    0.241916      1266        0.758084    0.484412        0.508230
# 248    430    0.259819      1225        0.740181    0.515588        0.491770
#
#           WOE            IV
# 0   -0.075007  6.892999e-03
# 1    0.089540  6.892999e-03
# 2    0.093774  6.892999e-03
# 3   -0.103711  5.447034e-03
# 4    0.046469  5.447034e-03
# 5    0.060609  5.447034e-03
# 6   -0.022092  4.847271e-04
# 7    0.021943  4.847271e-04
# 8    0.080151  3.328100e-03
# 9   -0.039583  3.328100e-03
# 10  -0.043436  3.328100e-03
# 11  -0.338301  1.025972e-01
# 12  -0.253867  1.025972e-01
# 13  -0.212228  1.025972e-01
# 14   0.060322  1.025972e-01
# 15   0.228446  1.025972e-01
# 16   0.556929  1.025972e-01
# 17  -0.192882  5.212598e-02
# 18  -0.099716  5.212598e-02
# 19   0.344846  5.212598e-02
# 20  -0.118577  1.909613e-02
# 21   0.161300  1.909613e-02
# 22   0.065749  3.360865e-03
# 23  -0.039913  3.360865e-03
# 24  -0.072229  3.360865e-03
# 25  -0.018304  5.806234e-04
# 26   0.031723  5.806234e-04
# 27   0.010954  1.521483e-02
# 28  -1.390701  1.521483e-02
# 29   0.008974  2.395949e-04
# 30  -0.026700  2.395949e-04
# 31   0.061812  3.948119e-03
# 32  -0.063894  3.948119e-03
# 33  -0.196778  3.738199e-02
# 34  -0.151428  3.738199e-02
# 35   0.080752  3.738199e-02
# 36   0.276133  3.738199e-02
# 37  -0.040424  1.637338e-03
# 38   0.040509  1.637338e-03
# 39  -0.016325  2.709315e-04
# 40   0.016596  2.709315e-04
# 41  -0.029357  8.539328e-04
# 42   0.029090  8.539328e-04
# 43   0.026437  7.556207e-04
# 44  -0.028584  7.556207e-04
# 45  -0.085752  7.878318e-03
# 46   0.091934  7.878318e-03
# 47  -0.302451  2.380118e-02
# 48  -0.021356  2.380118e-02
# 49  -0.010676  2.380118e-02
# ..        ...           ...
# 199  0.129292  9.685276e-03
# 200 -0.001541  9.685276e-03
# 201 -0.084449  9.685276e-03
# 202 -0.117873  9.685276e-03
# 203  0.000210  1.001985e-07
# 204 -0.000477  1.001985e-07
# 205 -0.094290  1.037809e-02
# 206 -0.046188  1.037809e-02
# 207  0.139201  1.037809e-02
# 208 -0.086419  1.441159e-02
# 209 -0.079672  1.441159e-02
# 210  0.172525  1.441159e-02
# 211  0.094368  1.096302e-02
# 212 -0.116280  1.096302e-02
# 213  0.119150  9.431560e-03
# 214 -0.008023  9.431560e-03
# 215 -0.118391  9.431560e-03
# 216  0.322766  4.666124e-02
# 217 -0.004406  4.666124e-02
# 218 -0.133864  4.666124e-02
# 219 -0.253945  4.666124e-02
# 220  0.039617  3.106153e-03
# 221 -0.078426  3.106153e-03
# 222  0.083396  2.537837e-02
# 223 -0.139748  2.537837e-02
# 224       NaN  2.537837e-02
# 225 -0.069379  2.537837e-02
# 226 -0.104877  2.537837e-02
# 227 -0.175224  2.537837e-02
# 228  0.191751  2.537837e-02
# 229  0.293428  2.537837e-02
# 230 -0.084609  1.072291e-02
# 231  0.126847  1.072291e-02
# 232  0.172969  2.104185e-02
# 233  0.048125  2.104185e-02
# 234 -0.046370  2.104185e-02
# 235 -0.248603  2.104185e-02
# 236  0.332921  5.959403e-02
# 237  0.237635  5.959403e-02
# 238  0.124010  5.959403e-02
# 239 -0.083768  5.959403e-02
# 240 -0.085142  5.959403e-02
# 241 -0.205077  5.959403e-02
# 242 -0.433402  5.959403e-02
# 243 -0.196134  3.431279e-02
# 244 -0.136578  3.431279e-02
# 245  0.053287  3.431279e-02
# 246  0.279516  3.431279e-02
# 247 -0.047997  2.269580e-03
# 248  0.047295  2.269580e-03
#
# [249 rows x 12 columns]

# %%
# cols_0_to_1
# cols_catg
# cols_date_diff
# col_nums

# %%
cols_merge = []
for col_list in [cols_0_to_1, cols_catg, cols_date_diff, col_nums, ['status']]:
    cols_merge.extend(col_list)

# %%
df = train_set[cols_merge].copy()

# %%
final_iv, IV = data_vars(df, df['status'])

# %%
IV.shape
# Out:
# (83, 2)

# %%
IV = IV.sort_values('IV', ascending=False).copy()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
IV[IV.IV > 0.1]
# Out:
#                                    VAR_NAME        IV
# 78   trans_fail_top_count_enum_last_1_month  0.544360
# 21                         history_fail_fee  0.539203
# 49                              loans_score  0.386329
# 2                               apply_score  0.341936
# 47                      loans_overdue_count  0.324504
# 77  trans_fail_top_count_enum_last_12_month  0.255894
# 79   trans_fail_top_count_enum_last_6_month  0.253871
# 26                    latest_one_month_fail  0.189220
# 63                        rank_trad_1_month  0.102597

# %%
IV = IV.reset_index(drop=True)

# %%
IV.to_clipboard()

# %%
obj = IV[IV.IV > 0.05]
obj
# Out:
#                                    VAR_NAME        IV
# 78   trans_fail_top_count_enum_last_1_month  0.544360
# 21                         history_fail_fee  0.539203
# 49                              loans_score  0.386329
# 2                               apply_score  0.341936
# 47                      loans_overdue_count  0.324504
# 77  trans_fail_top_count_enum_last_12_month  0.255894
# 79   trans_fail_top_count_enum_last_6_month  0.253871
# 26                    latest_one_month_fail  0.189220
# 63                        rank_trad_1_month  0.102597
# 28                     latest_one_month_suc  0.097409
# 53     max_cumulative_consume_later_1_month  0.083718
# 74                  trans_day_last_12_month  0.063021
# 6                         consfin_avg_limit  0.059594
# 69             top_trans_count_last_1_month  0.052126

# %%
# IV值挑选出的变量
# 'trans_fail_top_count_enum_last_1_month',
#  'history_fail_fee',
#  'loans_score',
#  'apply_score',
#  'loans_overdue_count',
#  'trans_fail_top_count_enum_last_12_month',
#  'trans_fail_top_count_enum_last_6_month',
#  'latest_one_month_fail',
#  'rank_trad_1_month',
obj['VAR_NAME'].tolist()
# Out:
# ['trans_fail_top_count_enum_last_1_month',
#  'history_fail_fee',
#  'loans_score',
#  'apply_score',
#  'loans_overdue_count',
#  'trans_fail_top_count_enum_last_12_month',
#  'trans_fail_top_count_enum_last_6_month',
#  'latest_one_month_fail',
#  'rank_trad_1_month',
#  'latest_one_month_suc',
#  'max_cumulative_consume_later_1_month',
#  'trans_day_last_12_month',
#  'consfin_avg_limit',
#  'top_trans_count_last_1_month']

# %% [markdown]
# ## 随机森林

# %% [markdown]
# https://blog.csdn.net/zjuPeco/article/details/77371645

# %%
df.head()
# Out:
#       low_volume_percent  middle_volume_percent  trans_activity_month  \
# 110                 0.01                   0.99                  1.00
# 3394                0.03                   0.97                  1.00
# 3052                0.02                   0.86                  0.70
# 490                 0.02                   0.81                  0.73
# 1                   0.02                   0.94                  1.00
#
#       trans_activity_day  rank_trad_1_month  top_trans_count_last_1_month  \
# 110                0.405               0.85                          1.00
# 3394               0.205               0.65                          0.40
# 3052               0.205               0.45                          0.30
# 490                0.555               0.30                          0.10
# 1                  0.458               0.35                          0.05
#
#       avg_price_top_last_12_valid_month  regional_mobility  student_feature  \
# 110                                0.45                  1                1
# 3394                               0.65                  3                0
# 3052                               0.55                  2                0
# 490                                0.45                  4                1
# 1                                  0.50                  4                1
#
#       is_high_user  reg_preference_for_trad  first_transaction_time_diff_day  \
# 110              0                        2                              469
# 3394             0                        2                              427
# 3052             0                        2                             1299
# 490              0                        4                             1749
# 1                0                        2                              790
#
#       latest_query_time_diff_day  loans_latest_time_diff_day  \
# 110                           28                          37
# 3394                          55                          52
# 3052                          28                         162
# 490                           45                          76
# 1                             29                          27
#
#       take_amount_in_later_12_month_highest  \
# 110                                    4000
# 3394                                    500
# 3052                                      0
# 490                                    1000
# 1                                      2000
#
#       trans_amount_increase_rate_lately  transd_mcc  \
# 110                                0.96        16.0
# 3394                               0.87        18.0
# 3052                               1.98        18.0
# 490                                1.49        23.0
# 1                                  1.28        19.0
#
#       trans_days_interval_filter  trans_days_interval  repayment_capability  \
# 110                         29.0                 28.0                 17570
# 3394                        27.0                 27.0                 15310
# 3052                        53.0                 33.0                 12240
# 490                         15.0                  8.0                  4320
# 1                           30.0                 14.0                 16970
#
#       number_of_trans_from_2011  historical_trans_amount  \
# 110                        13.0                   181770
# 3394                       12.0                    63350
# 3052                       28.0                    97190
# 490                        40.0                   373700
# 1                          23.0                   302910
#
#       historical_trans_day  trans_amount_3_month  \
# 110                  150.0                 15610
# 3394                  74.0                 12200
# 3052                  93.0                 33280
# 490                  356.0                 61940
# 1                    224.0                 10590
#
#       avg_consume_less_12_valid_month    abs  avg_price_last_12_month  \
# 110                               7.0   2650                     1220
# 3394                              6.0   3460                      630
# 3052                              8.0   1060                      930
# 490                               8.0  26200                     1390
# 1                                 5.0   6950                     1210
#
#       trans_top_time_last_1_month  trans_top_time_last_6_month  \
# 110                           0.0                         29.0
# 3394                         14.0                         17.0
# 3052                         11.0                         21.0
# 490                          15.0                         15.0
# 1                            13.0                         30.0
#
#       consume_top_time_last_1_month  consume_top_time_last_6_month  \
# 110                             0.0                           29.0
# 3394                           14.0                           17.0
# 3052                           11.0                           21.0
# 490                            15.0                           15.0
# 1                              13.0                           30.0
#
#       cross_consume_count_last_1_month  \
# 110                                0.0
# 3394                               1.0
# 3052                               0.0
# 490                                1.0
# 1                                  0.0
#
#       trans_fail_top_count_enum_last_1_month  \
# 110                                      6.0
# 3394                                     1.0
# 3052                                     0.0
# 490                                      8.0
# 1                                        0.0
#
#       trans_fail_top_count_enum_last_6_month  \
# 110                                      9.0
# 3394                                     4.0
# 3052                                     4.0
# 490                                      8.0
# 1                                        3.0
#
#       trans_fail_top_count_enum_last_12_month  consume_mini_time_last_1_month  \
# 110                                       9.0                             0.0
# 3394                                      9.0                             0.0
# 3052                                     21.0                             0.0
# 490                                       8.0                         42936.0
# 1                                         3.0                           330.0
#
#       max_cumulative_consume_later_1_month  max_consume_count_later_6_month  \
# 110                                    220                              6.0
# 3394                                   470                              4.0
# 3052                                  1950                             12.0
# 490                                   3090                              7.0
# 1                                     2100                              9.0
#
#       railway_consume_count_last_12_month  \
# 110                                   0.0
# 3394                                  0.0
# 3052                                  0.0
# 490                                   0.0
# 1                                     0.0
#
#       pawns_auctions_trusts_consume_last_1_month  \
# 110                                            0
# 3394                                         470
# 3052                                        1950
# 490                                         3140
# 1                                           1820
#
#       pawns_auctions_trusts_consume_last_6_month  \
# 110                                        10160
# 3394                                        2060
# 3052                                        8240
# 490                                        67720
# 1                                          15680
#
#       jewelry_consume_count_last_6_month  first_transaction_day  \
# 110                                  0.0                  458.0
# 3394                                 0.0                  416.0
# 3052                                 0.0                 1288.0
# 490                                  0.0                 1738.0
# 1                                    0.0                  779.0
#
#       trans_day_last_12_month  apply_score  apply_credibility  \
# 110                      99.0        535.0               73.0
# 3394                     82.0        540.0               81.0
# 3052                     82.0        516.0               75.0
# 490                      82.0        491.0               74.0
# 1                        84.0        653.0               73.0
#
#       query_org_count  query_finance_count  query_cash_count  query_sum_count  \
# 110              16.0                  6.0               7.0             24.0
# 3394              8.0                  3.0               3.0              9.0
# 3052             14.0                  8.0               6.0             19.0
# 490              11.0                  6.0               4.0             12.0
# 1                 7.0                  4.0               2.0              8.0
#
#       latest_one_month_apply  latest_three_month_apply  \
# 110                      5.0                      12.0
# 3394                     1.0                       3.0
# 3052                     5.0                       8.0
# 490                      1.0                       4.0
# 1                        2.0                       6.0
#
#       latest_six_month_apply  loans_score  loans_credibility_behavior  \
# 110                     15.0        498.0                        73.0
# 3394                     6.0        510.0                        76.0
# 3052                    12.0        482.0                        77.0
# 490                      7.0        448.0                        78.0
# 1                        8.0        635.0                        76.0
#
#       loans_count  loans_settle_count  loans_overdue_count  \
# 110          92.0                77.0                  7.0
# 3394         19.0                16.0                  3.0
# 3052         16.0                16.0                  2.0
# 490          40.0                22.0                  7.0
# 1            37.0                36.0                  0.0
#
#       loans_org_count_behavior  consfin_org_count_behavior  loans_cash_count  \
# 110                       27.0                         7.0              20.0
# 3394                       7.0                         5.0               2.0
# 3052                       8.0                         5.0               3.0
# 490                       17.0                        11.0               6.0
# 1                         17.0                         5.0              12.0
#
#       latest_one_month_loan  latest_three_month_loan  latest_six_month_loan  \
# 110                     1.0                      3.0                   34.0
# 3394                    1.0                      1.0                    5.0
# 3052                    0.0                      0.0                    7.0
# 490                     0.0                      3.0                   18.0
# 1                       2.0                      2.0                    8.0
#
#       history_suc_fee  history_fail_fee  latest_one_month_suc  \
# 110              85.0              52.0                   0.0
# 3394             22.0              11.0                   1.0
# 3052             20.0               5.0                   0.0
# 490              40.0              78.0                   0.0
# 1                49.0               4.0                   2.0
#
#       latest_one_month_fail  loans_long_time  loans_credit_limit  \
# 110                     3.0            356.0              2400.0
# 3394                    0.0            357.0              2400.0
# 3052                    0.0            314.0              1400.0
# 490                    10.0            356.0              2600.0
# 1                       1.0            353.0              2000.0
#
#       loans_credibility_limit  loans_org_count_current  loans_product_count  \
# 110                      72.0                     20.0                 22.0
# 3394                     73.0                      2.0                  2.0
# 3052                     66.0                      3.0                  3.0
# 490                      76.0                      6.0                  7.0
# 1                        74.0                     12.0                 12.0
#
#       loans_max_limit  loans_avg_limit  consfin_credit_limit  \
# 110            5000.0           1845.0               10600.0
# 3394           2600.0           1800.0               16300.0
# 3052           2300.0           1500.0               10400.0
# 490            4500.0           2500.0                6600.0
# 1              3500.0           1758.0               15100.0
#
#       consfin_credibility  consfin_org_count_current  consfin_product_count  \
# 110                  81.0                        7.0                    7.0
# 3394                 78.0                        5.0                    5.0
# 3052                 82.0                        5.0                    5.0
# 490                  78.0                       11.0                   12.0
# 1                    80.0                        5.0                    6.0
#
#       consfin_max_limit  consfin_avg_limit  latest_query_day  \
# 110             15600.0             8228.0               0.0
# 3394            21600.0             7160.0              30.0
# 3052            13800.0            10320.0               3.0
# 490             17400.0             6418.0              20.0
# 1               22800.0             9360.0               4.0
#
#       loans_latest_day  status
# 110                9.0       1
# 3394              27.0       0
# 3052             137.0       0
# 490               51.0       1
# 1                  2.0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3325 entries, 110 to 1274
# Data columns (total 84 columns):
# low_volume_percent                            3325 non-null float64
# middle_volume_percent                         3325 non-null float64
# trans_activity_month                          3325 non-null float64
# trans_activity_day                            3325 non-null float64
# rank_trad_1_month                             3325 non-null float64
# top_trans_count_last_1_month                  3325 non-null float64
# avg_price_top_last_12_valid_month             3325 non-null float64
# regional_mobility                             3325 non-null int64
# student_feature                               3325 non-null int64
# is_high_user                                  3325 non-null int64
# reg_preference_for_trad                       3325 non-null int64
# first_transaction_time_diff_day               3325 non-null int64
# latest_query_time_diff_day                    3325 non-null int64
# loans_latest_time_diff_day                    3325 non-null int64
# take_amount_in_later_12_month_highest         3325 non-null int64
# trans_amount_increase_rate_lately             3325 non-null float64
# transd_mcc                                    3325 non-null float64
# trans_days_interval_filter                    3325 non-null float64
# trans_days_interval                           3325 non-null float64
# repayment_capability                          3325 non-null int64
# number_of_trans_from_2011                     3325 non-null float64
# historical_trans_amount                       3325 non-null int64
# historical_trans_day                          3325 non-null float64
# trans_amount_3_month                          3325 non-null int64
# avg_consume_less_12_valid_month               3325 non-null float64
# abs                                           3325 non-null int64
# avg_price_last_12_month                       3325 non-null int64
# trans_top_time_last_1_month                   3325 non-null float64
# trans_top_time_last_6_month                   3325 non-null float64
# consume_top_time_last_1_month                 3325 non-null float64
# consume_top_time_last_6_month                 3325 non-null float64
# cross_consume_count_last_1_month              3325 non-null float64
# trans_fail_top_count_enum_last_1_month        3325 non-null float64
# trans_fail_top_count_enum_last_6_month        3325 non-null float64
# trans_fail_top_count_enum_last_12_month       3325 non-null float64
# consume_mini_time_last_1_month                3325 non-null float64
# max_cumulative_consume_later_1_month          3325 non-null int64
# max_consume_count_later_6_month               3325 non-null float64
# railway_consume_count_last_12_month           3325 non-null float64
# pawns_auctions_trusts_consume_last_1_month    3325 non-null int64
# pawns_auctions_trusts_consume_last_6_month    3325 non-null int64
# jewelry_consume_count_last_6_month            3325 non-null float64
# first_transaction_day                         3325 non-null float64
# trans_day_last_12_month                       3325 non-null float64
# apply_score                                   3325 non-null float64
# apply_credibility                             3325 non-null float64
# query_org_count                               3325 non-null float64
# query_finance_count                           3325 non-null float64
# query_cash_count                              3325 non-null float64
# query_sum_count                               3325 non-null float64
# latest_one_month_apply                        3325 non-null float64
# latest_three_month_apply                      3325 non-null float64
# latest_six_month_apply                        3325 non-null float64
# loans_score                                   3325 non-null float64
# loans_credibility_behavior                    3325 non-null float64
# loans_count                                   3325 non-null float64
# loans_settle_count                            3325 non-null float64
# loans_overdue_count                           3325 non-null float64
# loans_org_count_behavior                      3325 non-null float64
# consfin_org_count_behavior                    3325 non-null float64
# loans_cash_count                              3325 non-null float64
# latest_one_month_loan                         3325 non-null float64
# latest_three_month_loan                       3325 non-null float64
# latest_six_month_loan                         3325 non-null float64
# history_suc_fee                               3325 non-null float64
# history_fail_fee                              3325 non-null float64
# latest_one_month_suc                          3325 non-null float64
# latest_one_month_fail                         3325 non-null float64
# loans_long_time                               3325 non-null float64
# loans_credit_limit                            3325 non-null float64
# loans_credibility_limit                       3325 non-null float64
# loans_org_count_current                       3325 non-null float64
# loans_product_count                           3325 non-null float64
# loans_max_limit                               3325 non-null float64
# loans_avg_limit                               3325 non-null float64
# consfin_credit_limit                          3325 non-null float64
# consfin_credibility                           3325 non-null float64
# consfin_org_count_current                     3325 non-null float64
# consfin_product_count                         3325 non-null float64
# consfin_max_limit                             3325 non-null float64
# consfin_avg_limit                             3325 non-null float64
# latest_query_day                              3325 non-null float64
# loans_latest_day                              3325 non-null float64
# status                                        3325 non-null int64
# dtypes: float64(67), int64(17)
# memory usage: 2.2 MB

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train, y_train = df.iloc[:, :-1].values, df['status'].values

# %%
x_train
# Out:
# array([[ 1.000e-02,  9.900e-01,  1.000e+00, ...,  8.228e+03,  0.000e+00,
#          9.000e+00],
#        [ 3.000e-02,  9.700e-01,  1.000e+00, ...,  7.160e+03,  3.000e+01,
#          2.700e+01],
#        [ 2.000e-02,  8.600e-01,  7.000e-01, ...,  1.032e+04,  3.000e+00,
#          1.370e+02],
#        ...,
#        [ 0.000e+00,  3.900e-01,  4.200e-01, ...,  5.900e+03,  6.000e+00,
#          5.000e+00],
#        [ 0.000e+00,  8.800e-01,  9.000e-01, ...,  7.028e+03, -9.990e+02,
#         -9.990e+02],
#        [ 1.000e-02,  9.000e-01,  7.700e-01, ...,  1.260e+04,  1.400e+01,
#          3.000e+01]])

# %%
y_train
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %%
forest = RandomForestClassifier(n_estimators=10000, random_state=2018, n_jobs=-1)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10000, n_jobs=-1,
#             oob_score=False, random_state=2018, verbose=0,
#             warm_start=False)

# %%
feat_labels = df.columns[:-1]

# %%
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(x_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))
# Out:
#  1) trans_fail_top_count_enum_last_1_month 0.052490
#  2) history_fail_fee               0.047691
#  3) loans_score                    0.036989
#  4) apply_score                    0.028979
#  5) loans_overdue_count            0.024626
#  6) latest_one_month_fail          0.021572
#  7) trans_amount_3_month           0.017184
#  8) trans_day_last_12_month        0.016095
#  9) max_cumulative_consume_later_1_month 0.016027
# 10) repayment_capability           0.015864
# 11) trans_fail_top_count_enum_last_6_month 0.015654
# 12) trans_fail_top_count_enum_last_12_month 0.015114
# 13) avg_price_last_12_month        0.014948
# 14) first_transaction_day          0.014770
# 15) abs                            0.014756
# 16) first_transaction_time_diff_day 0.014739
# 17) trans_amount_increase_rate_lately 0.014693
# 18) consfin_avg_limit              0.014687
# 19) historical_trans_amount        0.014651
# 20) latest_query_day               0.013981
# 21) latest_query_time_diff_day     0.013933
# 22) trans_activity_day             0.013916
# 23) historical_trans_day           0.013895
# 24) pawns_auctions_trusts_consume_last_6_month 0.013576
# 25) loans_avg_limit                0.013487
# 26) trans_days_interval_filter     0.013273
# 27) consfin_credit_limit           0.012802
# 28) trans_days_interval            0.012744
# 29) history_suc_fee                0.012730
# 30) loans_latest_day               0.012399
# 31) loans_latest_time_diff_day     0.012212
# 32) trans_top_time_last_6_month    0.011994
# 33) number_of_trans_from_2011      0.011914
# 34) consume_top_time_last_6_month  0.011855
# 35) loans_long_time                0.011749
# 36) consfin_max_limit              0.011515
# 37) rank_trad_1_month              0.011391
# 38) loans_max_limit                0.011288
# 39) trans_activity_month           0.011217
# 40) loans_settle_count             0.011215
# 41) trans_top_time_last_1_month    0.011156
# 42) apply_credibility              0.010868
# 43) loans_count                    0.010856
# 44) consume_top_time_last_1_month  0.010670
# 45) transd_mcc                     0.010515
# 46) query_sum_count                0.010069
# 47) take_amount_in_later_12_month_highest 0.010035
# 48) loans_credit_limit             0.009960
# 49) consfin_credibility            0.009890
# 50) latest_six_month_loan          0.009835
# 51) middle_volume_percent          0.009733
# 52) consume_mini_time_last_1_month 0.009727
# 53) latest_one_month_suc           0.009636
# 54) latest_six_month_apply         0.009567
# 55) max_consume_count_later_6_month 0.009314
# 56) loans_org_count_behavior       0.009200
# 57) pawns_auctions_trusts_consume_last_1_month 0.009095
# 58) latest_three_month_apply       0.009056
# 59) query_org_count                0.009008
# 60) avg_price_top_last_12_valid_month 0.008982
# 61) query_finance_count            0.008519
# 62) loans_credibility_limit        0.008422
# 63) loans_credibility_behavior     0.008378
# 64) latest_one_month_apply         0.007782
# 65) latest_three_month_loan        0.007733
# 66) loans_product_count            0.007686
# 67) loans_cash_count               0.007415
# 68) loans_org_count_current        0.007412
# 69) query_cash_count               0.007313
# 70) low_volume_percent             0.007133
# 71) consfin_product_count          0.007078
# 72) top_trans_count_last_1_month   0.006712
# 73) consfin_org_count_behavior     0.006539
# 74) consfin_org_count_current      0.006526
# 75) avg_consume_less_12_valid_month 0.006325
# 76) regional_mobility              0.004739
# 77) latest_one_month_loan          0.003395
# 78) cross_consume_count_last_1_month 0.003354
# 79) reg_preference_for_trad        0.002878
# 80) student_feature                0.001748
# 81) railway_consume_count_last_12_month 0.000797
# 82) jewelry_consume_count_last_6_month 0.000242
# 83) is_high_user                   0.000085

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ls
# Out:
# 2019-08-09/                        task01.ipynb
# README.md                          task01_52_lmingzhi.html
# Untitled.ipynb                     task02_IV_RF_特征重要性.xlsx
# data.csv                           task02_特征挑选.ipynb
# others/

# %% [markdown]
# # 问题

# %% [markdown]
# 1. IV值有较好的介绍教材吗，需要更深入了解IV值的定义
# 2. 特征IV值和RF特征重要性阈值设为多少合适？
